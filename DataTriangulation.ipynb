# %% [markdown]
# ## Importing the essential libraries over here

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
import numpy as np
pd.set_option('display.float_format', '{:.6f}'.format)
pd.set_option('display.float_format', lambda x: "{:.6f}".format(x) if not pd.isna(x) else "NaN")

# %% [markdown]
# ## Importing the Reference datasets over here

# %%
AahaarAnudan_df=pd.read_csv("../data/Tables-Sampledata/AahaarAnudan.csv",low_memory=False)

# %%
AahaarAnudan_df.head(2)
# Out:
#   ApplicationID Beneficiary_Name Father/HusbandName              DateOFBirth  \
# 0    AA00004493        Tersi bai                NaN  1988-01-01 00:00:00.000
# 1    AA00038674        SAJAN BAI       W/O: Bhanwar  1979-01-01 00:00:00.000
#
#   District    Block       GP  Village Cast SubCaste  SamagraID  \
# 0   Umaria     Pali   Gijari      NaN   ST    Baiga  100560904
# 1  Dindori  Amarpur  RAMPURI  RAMPURI   ST    Baiga  100614458
#
#    SamagraFamilyID eEKYC_Status Profile_Status                eKYC_Date  \
# 0         20133068          Yes         Active  2023-04-21 15:20:00.000
# 1         20145994          Yes         Active  2023-04-13 15:55:00.000
#
#    Project_status         DOB  Gender   RefKey_of_Beneficiaries  \
# 0             NaN  1988-01-01  Female 194269509179031456.000000
# 1             NaN  1979-01-01  Female                  0.000000
#
#   Aadhaar_Anudaan_Registration_Date  Insert_Date_Time  DePtID  SchemeID  \
# ...

# %%
AahaarAnudan_df.columns
# Out:
# Index(['ApplicationID', 'Beneficiary_Name', 'Father/HusbandName',
#        'DateOFBirth', 'District', 'Block', 'GP', 'Village', 'Cast', 'SubCaste',
#        'SamagraID', 'SamagraFamilyID', 'eEKYC_Status', 'Profile_Status',
#        'eKYC_Date', 'Project_status', 'DOB', 'Gender',
#        'RefKey_of_Beneficiaries', 'Aadhaar_Anudaan_Registration_Date',
#        'Insert_Date_Time', 'DePtID', 'SchemeID', 'Active', 'Remark'],
#       dtype='object')

# %% [markdown]
# ## Performing the Column selections over here

# %%
selected_AahaarAnudan_df=AahaarAnudan_df[['ApplicationID', 'Beneficiary_Name', 'Father/HusbandName',
       'DateOFBirth', 'District', 'Block', 'Village', 'Cast',
       'RefKey_of_Beneficiaries', 'Aadhaar_Anudaan_Registration_Date',
       'DePtID', 'SchemeID']]

# %%
# dataframe after performing the column selection over here
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name        Father/HusbandName  \
# 0    AA00004493        Tersi bai                       NaN
# 1    AA00038674        SAJAN BAI              W/O: Bhanwar
# 2    AA00039668            BUNDI                 FUL SINGH
# 3    AA00062254           Mango           Chota No Sirneme
# 4    AA00216038        BHAGVATI            Tularam Adivasi
# 5    AA00224410            MUNNI  Ranveer Singh No Sirname
# 6    AA00224415          PARBATI          Pappu No Siranme
# 7    AA00232121        Rampi Bai             Mahipal Baiga
# 8    AA00233877           SHANTI             Karan Adiwasi
# 9    AA00240399    REENA ADIVASI             VIJAY ADIWASI
#
#                DateOFBirth    District       Block         Village Cast  \
# 0  1988-01-01 00:00:00.000      Umaria        Pali             NaN   ST
# 1  1979-01-01 00:00:00.000     Dindori     Amarpur         RAMPURI   ST
# 2  1985-01-05 00:00:00.000     Dindori     Amarpur         Rampuri  NaN
# ...

# %%
selected_AahaarAnudan_df_initial=selected_AahaarAnudan_df.copy()

# %%
selected_AahaarAnudan_df.shape
# Out:
# (10, 12)

# %%
len(selected_AahaarAnudan_df['ApplicationID'].unique())
# Out:
# 10

# %% [markdown]
# Observation
# - ApplicationID is the primary key over here

# %% [markdown]
# ## Performing the Data Cleansing over here

# %%
## removing the duplicate entries

# %%
selected_AahaarAnudan_df.duplicated().sum()
# Out:
# 0

# %%
selected_AahaarAnudan_df.drop_duplicates(inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7796\1750919136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df.drop_duplicates(inplace=True)

# %% [markdown]
# Observation
# - We don't have any duplicate observations over here

# %% [markdown]
# ## Handling Garbage Values over here
# Identify and handle irrelevant and non-logical data entries that do not contribute to the analysis and insights. This activity shall involve filtering out outliers or irrelevant data entries.

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name        Father/HusbandName  \
# 0    AA00004493        Tersi bai                       NaN
# 1    AA00038674        SAJAN BAI              W/O: Bhanwar
# 2    AA00039668            BUNDI                 FUL SINGH
# 3    AA00062254           Mango           Chota No Sirneme
# 4    AA00216038        BHAGVATI            Tularam Adivasi
# 5    AA00224410            MUNNI  Ranveer Singh No Sirname
# 6    AA00224415          PARBATI          Pappu No Siranme
# 7    AA00232121        Rampi Bai             Mahipal Baiga
# 8    AA00233877           SHANTI             Karan Adiwasi
# 9    AA00240399    REENA ADIVASI             VIJAY ADIWASI
#
#                DateOFBirth    District       Block         Village Cast  \
# 0  1988-01-01 00:00:00.000      Umaria        Pali             NaN   ST
# 1  1979-01-01 00:00:00.000     Dindori     Amarpur         RAMPURI   ST
# 2  1985-01-05 00:00:00.000     Dindori     Amarpur         Rampuri  NaN
# ...

# %% [markdown]
# Observation
# - We don't have such observations in the above dataframe over here

# %% [markdown]
# ## Handling Missing Values
# The system should implement strategies to handle missing or null values, such as missing values in records of citizens etc. or removal of records with missing values.

# %%
selected_AahaarAnudan_df.isnull().sum()
# Out:
# ApplicationID                        0
# Beneficiary_Name                     0
# Father/HusbandName                   1
# DateOFBirth                          0
# District                             0
# Block                                0
# Village                              1
# Cast                                 2
# RefKey_of_Beneficiaries              2
# Aadhaar_Anudaan_Registration_Date    1
# DePtID                               0
# SchemeID                             0
# dtype: int64

# %%
missing_values=[feature for feature in selected_AahaarAnudan_df.columns if selected_AahaarAnudan_df[feature].isnull().sum()>=1]
for feature in missing_values:
    print(feature)
# Out:
# Father/HusbandName
# Village
# Cast
# RefKey_of_Beneficiaries
# Aadhaar_Anudaan_Registration_Date

# %%
selected_AahaarAnudan_df[missing_values]
# Out:
#          Father/HusbandName         Village Cast   RefKey_of_Beneficiaries  \
# 0                       NaN             NaN   ST 194269509179031456.000000
# 1              W/O: Bhanwar         RAMPURI   ST                  0.000000
# 2                 FUL SINGH         Rampuri  NaN                       NaN
# 3          Chota No Sirneme      bhonslegao   ST 287993394052219936.000000
# 4           Tularam Adivasi       UMMEDGARH   ST                  0.000000
# 5  Ranveer Singh No Sirname     BHONSLEGAON   ST 556960043973309824.000000
# 6          Pappu No Siranme     BHONSLEGAON   ST 245654937535116192.000000
# 7             Mahipal Baiga         Ginjri    ST 858644199876731136.000000
# 8             Karan Adiwasi           KARRA   ST 882770800328247680.000000
# 9             VIJAY ADIWASI  Jambada Bujurg  NaN                       NaN
#
#   Aadhaar_Anudaan_Registration_Date
# 0           2020-08-19 17:29:49.403
# 1           2020-08-19 17:29:49.403
# ...

# %% [markdown]
# Observation
# - One way is that we can remove the entire observation having missing values over here (Best)
# - Second way is that for categorical features we can replace missing values with "Missing" Indicator

# %% [markdown]
# ## Dropping the entire observation where we have missing values over here

# %%
selected_AahaarAnudan_df.dropna(inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\4289968178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df.dropna(inplace=True)

# %%
selected_AahaarAnudan_df[missing_values]
# Out:
#          Father/HusbandName      Village Cast   RefKey_of_Beneficiaries  \
# 1              W/O: Bhanwar      RAMPURI   ST                  0.000000
# 3          Chota No Sirneme   bhonslegao   ST 287993394052219936.000000
# 4           Tularam Adivasi    UMMEDGARH   ST                  0.000000
# 5  Ranveer Singh No Sirname  BHONSLEGAON   ST 556960043973309824.000000
# 6          Pappu No Siranme  BHONSLEGAON   ST 245654937535116192.000000
# 7             Mahipal Baiga      Ginjri    ST 858644199876731136.000000
# 8             Karan Adiwasi        KARRA   ST 882770800328247680.000000
#
#   Aadhaar_Anudaan_Registration_Date
# 1           2020-08-19 17:29:49.403
# 3           2020-08-19 17:29:49.403
# 4           2020-12-06 11:17:42.663
# 5           2020-12-30 13:25:12.187
# 6           2020-12-30 13:30:25.513
# 7           2021-02-25 05:47:46.407
# 8           2021-03-31 09:13:39.880

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name        Father/HusbandName  \
# 1    AA00038674        SAJAN BAI              W/O: Bhanwar
# 3    AA00062254           Mango           Chota No Sirneme
# 4    AA00216038        BHAGVATI            Tularam Adivasi
# 5    AA00224410            MUNNI  Ranveer Singh No Sirname
# 6    AA00224415          PARBATI          Pappu No Siranme
# 7    AA00232121        Rampi Bai             Mahipal Baiga
# 8    AA00233877           SHANTI             Karan Adiwasi
#
#                DateOFBirth    District       Block      Village Cast  \
# 1  1979-01-01 00:00:00.000     Dindori     Amarpur      RAMPURI   ST
# 3  1975-04-03 00:00:00.000  Ashoknagar  Ashoknagar   bhonslegao   ST
# 4  1985-01-01 00:00:00.000     Gwalior   Ghatigaon    UMMEDGARH   ST
# 5  1976-01-01 00:00:00.000  Ashoknagar  Ashoknagar  BHONSLEGAON   ST
# 6  1988-01-01 00:00:00.000  Ashoknagar  Ashoknagar  BHONSLEGAON   ST
# 7  1989-01-01 00:00:00.000      Umaria        Pali      Ginjri    ST
# ...

# %% [markdown]
# ## Standardizing formats
# The system must ensure consistency in data formats across different attributes and/or datasets. This may involve converting the raw data into a common, standardized and consumable format (e.g. date (DD/MM/YYYY), numbers, gender, first name, suffix, last name, etc.) to facilitate easier comparison, merging and analysis.

# %%
numerical_feature=[feature for feature in selected_AahaarAnudan_df.columns if selected_AahaarAnudan_df[feature].dtype!="O"]
for feature in numerical_feature:
    print(feature)
# Out:
# RefKey_of_Beneficiaries
# DePtID
# SchemeID

# %%
cat_feature=[feature for feature in selected_AahaarAnudan_df.columns if selected_AahaarAnudan_df[feature].dtype=="O"]
for feature in cat_feature:
    print(feature)
# Out:
# ApplicationID
# Beneficiary_Name
# Father/HusbandName
# DateOFBirth
# District
# Block
# Village
# Cast
# Aadhaar_Anudaan_Registration_Date

# %% [markdown]
# ## Fetching all the features having Date in it over here

# %%
date_feature = [feature for feature in cat_feature if 'Yr' in feature or 'Year' in feature or "yr" in feature or "year" in feature or "Date" in feature]
date_feature
# Out:
# ['DateOFBirth', 'Aadhaar_Anudaan_Registration_Date']

# %%
# Convert selected columns to datetime format
for col in date_feature:
    selected_AahaarAnudan_df[col] = pd.to_datetime(selected_AahaarAnudan_df[col], format='%Y-%m-%d')

# Convert datetime format to 'dd/mm/yyyy' format
for col in date_feature:
    selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].dt.strftime('%d/%m/%Y')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\3964040395.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[col] = pd.to_datetime(selected_AahaarAnudan_df[col], format='%Y-%m-%d')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\3964040395.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[col] = pd.to_datetime(selected_AahaarAnudan_df[col], format='%Y-%m-%d')
# ...

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name        Father/HusbandName DateOFBirth  \
# 1    AA00038674        SAJAN BAI              W/O: Bhanwar  01/01/1979
# 3    AA00062254           Mango           Chota No Sirneme  03/04/1975
# 4    AA00216038        BHAGVATI            Tularam Adivasi  01/01/1985
# 5    AA00224410            MUNNI  Ranveer Singh No Sirname  01/01/1976
# 6    AA00224415          PARBATI          Pappu No Siranme  01/01/1988
# 7    AA00232121        Rampi Bai             Mahipal Baiga  01/01/1989
# 8    AA00233877           SHANTI             Karan Adiwasi  01/01/1967
#
#      District       Block      Village Cast   RefKey_of_Beneficiaries  \
# 1     Dindori     Amarpur      RAMPURI   ST                  0.000000
# 3  Ashoknagar  Ashoknagar   bhonslegao   ST 287993394052219936.000000
# 4     Gwalior   Ghatigaon    UMMEDGARH   ST                  0.000000
# 5  Ashoknagar  Ashoknagar  BHONSLEGAON   ST 556960043973309824.000000
# ...

# %% [markdown]
# Observation
# - Sometimes what will happen will be first name and last name in separate columns we need to combine both of them to create full name
# - and many more such cases

# %% [markdown]
# ## Naming Standardizing over here
# Names are standardized based on similar sounding letters/patterns used in Indian names.
# - Replace adjacent similar characters by single character. E.g. “aa” replaced by “a”, “”bb” replaced by “b” etc.

# %%
## Converting the categories into lower case for applying the naming standardization properly
def convert_to_lower(name):
    return name.lower()

# %%
selected_AahaarAnudan_df[cat_feature] = selected_AahaarAnudan_df[cat_feature].applymap(convert_to_lower)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\1858644449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[cat_feature] = selected_AahaarAnudan_df[cat_feature].applymap(convert_to_lower)

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name        Father/HusbandName DateOFBirth  \
# 1    aa00038674        sajan bai              w/o: bhanwar  01/01/1979
# 3    aa00062254           mango           chota no sirneme  03/04/1975
# 4    aa00216038        bhagvati            tularam adivasi  01/01/1985
# 5    aa00224410            munni  ranveer singh no sirname  01/01/1976
# 6    aa00224415          parbati          pappu no siranme  01/01/1988
# 7    aa00232121        rampi bai             mahipal baiga  01/01/1989
# 8    aa00233877           shanti             karan adiwasi  01/01/1967
#
#      District       Block      Village Cast   RefKey_of_Beneficiaries  \
# 1     dindori     amarpur      rampuri   st                  0.000000
# 3  ashoknagar  ashoknagar   bhonslegao   st 287993394052219936.000000
# 4     gwalior   ghatigaon    ummedgarh   st                  0.000000
# 5  ashoknagar  ashoknagar  bhonslegaon   st 556960043973309824.000000
# ...

# %%
def replace_adjacent_duplicates(value):
    import re
    if isinstance(value, str):
        return re.sub(r'(.)\1+', r'\1', value)
    else:
        return value

# %%
cat_feature
# Out:
# ['ApplicationID',
#  'Beneficiary_Name',
#  'Father/HusbandName',
#  'DateOFBirth',
#  'District',
#  'Block',
#  'Village',
#  'Cast',
#  'Aadhaar_Anudaan_Registration_Date']

# %%
selected_AahaarAnudan_df[cat_feature] = selected_AahaarAnudan_df[cat_feature].applymap(replace_adjacent_duplicates)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\4086845694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[cat_feature] = selected_AahaarAnudan_df[cat_feature].applymap(replace_adjacent_duplicates)

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name       Father/HusbandName DateOFBirth  \
# 1       a038674        sajan bai             w/o: bhanwar  01/01/1979
# 3        a06254           mango          chota no sirneme  03/04/1975
# 4      a0216038        bhagvati           tularam adivasi  01/01/1985
# 5        a02410             muni  ranver singh no sirname  01/01/1976
# 6        a02415          parbati          papu no siranme   01/01/198
# 7      a0232121        rampi bai            mahipal baiga  01/01/1989
# 8        a02387           shanti            karan adiwasi  01/01/1967
#
#      District       Block      Village Cast   RefKey_of_Beneficiaries  \
# 1     dindori     amarpur      rampuri   st                  0.000000
# 3  ashoknagar  ashoknagar   bhonslegao   st 287993394052219936.000000
# 4     gwalior   ghatigaon     umedgarh   st                  0.000000
# 5  ashoknagar  ashoknagar  bhonslegaon   st 556960043973309824.000000
# ...

# %%
def replace_characters(name):
    replacements = {'e': 'i', 'j': 'z', 'v': 'w', 'q': 'k'}
    for old, new in replacements.items():
        name = name.replace(old, new)
    return name

# %%
selected_AahaarAnudan_df[cat_feature] = selected_AahaarAnudan_df[cat_feature].applymap(replace_characters)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\4238718020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[cat_feature] = selected_AahaarAnudan_df[cat_feature].applymap(replace_characters)

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name       Father/HusbandName DateOFBirth  \
# 1       a038674        sazan bai             w/o: bhanwar  01/01/1979
# 3        a06254           mango          chota no sirnimi  03/04/1975
# 4      a0216038        bhagwati           tularam adiwasi  01/01/1985
# 5        a02410             muni  ranwir singh no sirnami  01/01/1976
# 6        a02415          parbati          papu no siranmi   01/01/198
# 7      a0232121        rampi bai            mahipal baiga  01/01/1989
# 8        a02387           shanti            karan adiwasi  01/01/1967
#
#      District       Block      Village Cast   RefKey_of_Beneficiaries  \
# 1     dindori     amarpur      rampuri   st                  0.000000
# 3  ashoknagar  ashoknagar   bhonsligao   st 287993394052219936.000000
# 4     gwalior   ghatigaon     umidgarh   st                  0.000000
# 5  ashoknagar  ashoknagar  bhonsligaon   st 556960043973309824.000000
# ...

# %% [markdown]
# ## Replacing the bigrams over here

# %%
def replace_bigrams(name):
    replacements = {'ph': 'f', 'gh': 'g', 'th': 't', 'kh': 'k', 'dh': 'd', 'ch': 'c', 'sh': 's', 'au': 'o',
                    'bh': 'b', 'ks': 'x', 'ck': 'k', 'ah': 'h'}
    for old, new in replacements.items():
        name = name.replace(old, new)
    return name

# %%
selected_AahaarAnudan_df[cat_feature] = selected_AahaarAnudan_df[cat_feature].applymap(replace_bigrams)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\496433814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[cat_feature] = selected_AahaarAnudan_df[cat_feature].applymap(replace_bigrams)

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name      Father/HusbandName DateOFBirth  \
# 1       a038674        sazan bai             w/o: banwar  01/01/1979
# 3        a06254           mango          cota no sirnimi  03/04/1975
# 4      a0216038         bagwati          tularam adiwasi  01/01/1985
# 5        a02410             muni  ranwir sing no sirnami  01/01/1976
# 6        a02415          parbati         papu no siranmi   01/01/198
# 7      a0232121        rampi bai            mhipal baiga  01/01/1989
# 8        a02387            santi           karan adiwasi  01/01/1967
#
#     District      Block     Village Cast   RefKey_of_Beneficiaries  \
# 1    dindori    amarpur     rampuri   st                  0.000000
# 3  asoknagar  asoknagar   bonsligao   st 287993394052219936.000000
# 4    gwalior   gatigaon    umidgarh   st                  0.000000
# 5  asoknagar  asoknagar  bonsligaon   st 556960043973309824.000000
# 6  asoknagar  asoknagar  bonsligaon   st 245654937535116192.000000
# ...

# %%
def remove_consonant_a(name):
    consonants = 'bcdfghjklmnpqrstvwxyz'
    new_name = ''
    for i in range(len(name)):
        if i > 0 and name[i] == 'a' and name[i - 1].lower() in consonants:
            continue  # Skip adding 'a' if it follows a consonant
        new_name += name[i]
    return new_name

# %%
selected_AahaarAnudan_df[cat_feature] = selected_AahaarAnudan_df[cat_feature].applymap(remove_consonant_a)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\853626296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[cat_feature] = selected_AahaarAnudan_df[cat_feature].applymap(remove_consonant_a)

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name    Father/HusbandName DateOFBirth District  \
# 1       a038674           szn bi             w/o: bnwr  01/01/1979  dindori
# 3        a06254            mngo         cot no sirnimi  03/04/1975  asokngr
# 4      a0216038           bgwti           tulrm adiwsi  01/01/1985   gwlior
# 5        a02410             muni  rnwir sing no sirnmi  01/01/1976  asokngr
# 6        a02415            prbti         ppu no sirnmi   01/01/198  asokngr
# 7      a0232121          rmpi bi             mhipl big  01/01/1989    umria
# 8        a02387             snti            krn adiwsi  01/01/1967   gwlior
#
#      Block    Village Cast   RefKey_of_Beneficiaries  \
# 1   amrpur     rmpuri   st                  0.000000
# 3  asokngr   bonsligo   st 287993394052219936.000000
# 4   gtigon    umidgrh   st                  0.000000
# 5  asokngr  bonsligon   st 556960043973309824.000000
# 6  asokngr  bonsligon   st 245654937535116192.000000
# ...

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name    Father/HusbandName DateOFBirth District  \
# 1       a038674           szn bi             w/o: bnwr  01/01/1979  dindori
# 3        a06254            mngo         cot no sirnimi  03/04/1975  asokngr
# 4      a0216038           bgwti           tulrm adiwsi  01/01/1985   gwlior
# 5        a02410             muni  rnwir sing no sirnmi  01/01/1976  asokngr
# 6        a02415            prbti         ppu no sirnmi   01/01/198  asokngr
# 7      a0232121          rmpi bi             mhipl big  01/01/1989    umria
# 8        a02387             snti            krn adiwsi  01/01/1967   gwlior
#
#      Block    Village Cast   RefKey_of_Beneficiaries  \
# 1   amrpur     rmpuri   st                  0.000000
# 3  asokngr   bonsligo   st 287993394052219936.000000
# 4   gtigon    umidgrh   st                  0.000000
# 5  asokngr  bonsligon   st 556960043973309824.000000
# 6  asokngr  bonsligon   st 245654937535116192.000000
# ...

# %% [markdown]
# ## Converting all the names into uppercase over here

# %%
def convert_to_uppercase(text):
    return text.upper()

# %%
for col in cat_feature:
    selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].apply(convert_to_uppercase)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\2547436842.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].apply(convert_to_uppercase)

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name    Father/HusbandName DateOFBirth District  \
# 1       A038674           SZN BI             W/O: BNWR  01/01/1979  DINDORI
# 3        A06254            MNGO         COT NO SIRNIMI  03/04/1975  ASOKNGR
# 4      A0216038           BGWTI           TULRM ADIWSI  01/01/1985   GWLIOR
# 5        A02410             MUNI  RNWIR SING NO SIRNMI  01/01/1976  ASOKNGR
# 6        A02415            PRBTI         PPU NO SIRNMI   01/01/198  ASOKNGR
# 7      A0232121          RMPI BI             MHIPL BIG  01/01/1989    UMRIA
# 8        A02387             SNTI            KRN ADIWSI  01/01/1967   GWLIOR
#
#      Block    Village Cast   RefKey_of_Beneficiaries  \
# 1   AMRPUR     RMPURI   ST                  0.000000
# 3  ASOKNGR   BONSLIGO   ST 287993394052219936.000000
# 4   GTIGON    UMIDGRH   ST                  0.000000
# 5  ASOKNGR  BONSLIGON   ST 556960043973309824.000000
# 6  ASOKNGR  BONSLIGON   ST 245654937535116192.000000
# ...

# %%
import re
salutation_patterns = [
    r'^Mr\.\s',
    r'^Mrs\.\s',
    r'^Ms\.\s',
    r'^Miss\.\s',
    r'^Master\.\s',
    r'^Dr\.\s',
    r'^Smt\.\s',
    r'^Sh\.\s'
]

# Function to remove salutations from names
def remove_salutations(text):
    for pattern in salutation_patterns:
        text = re.sub(pattern, '', text)
    return text.strip()

# Apply the function to each categorical column
for col in cat_feature:
    selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].apply(remove_salutations)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\3582110556.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].apply(remove_salutations)

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name    Father/HusbandName DateOFBirth District  \
# 1       A038674           SZN BI             W/O: BNWR  01/01/1979  DINDORI
# 3        A06254             MNGO        COT NO SIRNIMI  03/04/1975  ASOKNGR
# 4      A0216038            BGWTI          TULRM ADIWSI  01/01/1985   GWLIOR
# 5        A02410             MUNI  RNWIR SING NO SIRNMI  01/01/1976  ASOKNGR
# 6        A02415            PRBTI         PPU NO SIRNMI   01/01/198  ASOKNGR
# 7      A0232121          RMPI BI             MHIPL BIG  01/01/1989    UMRIA
# 8        A02387             SNTI            KRN ADIWSI  01/01/1967   GWLIOR
#
#      Block    Village Cast   RefKey_of_Beneficiaries  \
# 1   AMRPUR     RMPURI   ST                  0.000000
# 3  ASOKNGR   BONSLIGO   ST 287993394052219936.000000
# 4   GTIGON    UMIDGRH   ST                  0.000000
# 5  ASOKNGR  BONSLIGON   ST 556960043973309824.000000
# 6  ASOKNGR  BONSLIGON   ST 245654937535116192.000000
# ...

# %%
relationship_patterns = [
    r'\bS/O\b', r'\bSO\s', r'\bS\sO\b',
    r'\bD/O\b', r'\bDO\s', r'\bD\sO\b',
    r'\bW/O\b', r'\bWO\s', r'\bW\sO\b'
]

def remove_relationship_markers(text):
    for pattern in relationship_patterns:
        text = re.sub(pattern, '', text)
    return text.strip()

for col in cat_feature:
    selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].apply(remove_relationship_markers)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\2262068324.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].apply(remove_relationship_markers)

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name    Father/HusbandName DateOFBirth District  \
# 1       A038674           SZN BI                : BNWR  01/01/1979  DINDORI
# 3        A06254             MNGO        COT NO SIRNIMI  03/04/1975  ASOKNGR
# 4      A0216038            BGWTI          TULRM ADIWSI  01/01/1985   GWLIOR
# 5        A02410             MUNI  RNWIR SING NO SIRNMI  01/01/1976  ASOKNGR
# 6        A02415            PRBTI         PPU NO SIRNMI   01/01/198  ASOKNGR
# 7      A0232121          RMPI BI             MHIPL BIG  01/01/1989    UMRIA
# 8        A02387             SNTI            KRN ADIWSI  01/01/1967   GWLIOR
#
#      Block    Village Cast   RefKey_of_Beneficiaries  \
# 1   AMRPUR     RMPURI   ST                  0.000000
# 3  ASOKNGR   BONSLIGO   ST 287993394052219936.000000
# 4   GTIGON    UMIDGRH   ST                  0.000000
# 5  ASOKNGR  BONSLIGON   ST 556960043973309824.000000
# 6  ASOKNGR  BONSLIGON   ST 245654937535116192.000000
# ...

# %%
cat_feature
# Out:
# ['ApplicationID',
#  'Beneficiary_Name',
#  'Father/HusbandName',
#  'DateOFBirth',
#  'District',
#  'Block',
#  'Village',
#  'Cast',
#  'Aadhaar_Anudaan_Registration_Date']

# %%
def remove_special_characters(text):
    return re.sub(r'[^A-Za-z\s]', '', text)

# %%
columns_to_clean = ['Beneficiary_Name','Father/HusbandName','District','Block','Village','Cast']

def remove_special_characters(text):
    return re.sub(r'[^A-Za-z\s]', '', text)

# Apply the function to each specified column
for col in columns_to_clean:
    selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].apply(remove_special_characters)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\3785924153.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].apply(remove_special_characters)

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name    Father/HusbandName DateOFBirth District  \
# 1       A038674           SZN BI                  BNWR  01/01/1979  DINDORI
# 3        A06254             MNGO        COT NO SIRNIMI  03/04/1975  ASOKNGR
# 4      A0216038            BGWTI          TULRM ADIWSI  01/01/1985   GWLIOR
# 5        A02410             MUNI  RNWIR SING NO SIRNMI  01/01/1976  ASOKNGR
# 6        A02415            PRBTI         PPU NO SIRNMI   01/01/198  ASOKNGR
# 7      A0232121          RMPI BI             MHIPL BIG  01/01/1989    UMRIA
# 8        A02387             SNTI            KRN ADIWSI  01/01/1967   GWLIOR
#
#      Block    Village Cast   RefKey_of_Beneficiaries  \
# 1   AMRPUR     RMPURI   ST                  0.000000
# 3  ASOKNGR   BONSLIGO   ST 287993394052219936.000000
# 4   GTIGON    UMIDGRH   ST                  0.000000
# 5  ASOKNGR  BONSLIGON   ST 556960043973309824.000000
# 6  ASOKNGR  BONSLIGON   ST 245654937535116192.000000
# ...

# %%
stop_words = [
    'devi', 'dei', 'debi',
    'kumar', 'kumaar', 'kumari', 'kumaari', 'kmr', 'kumr',
    'bhai', 'bhau', 'bai',
    'ben',
    'singh', 'kaur',
    'Md', 'Mohd', 'Mohammad', 'Mohamad'
]

def remove_stop_words(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

for col in columns_to_clean:
    selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].apply(remove_stop_words)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\1486308465.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df[col] = selected_AahaarAnudan_df[col].apply(remove_stop_words)

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name    Father/HusbandName DateOFBirth District  \
# 1       A038674           SZN BI                  BNWR  01/01/1979  DINDORI
# 3        A06254             MNGO        COT NO SIRNIMI  03/04/1975  ASOKNGR
# 4      A0216038            BGWTI          TULRM ADIWSI  01/01/1985   GWLIOR
# 5        A02410             MUNI  RNWIR SING NO SIRNMI  01/01/1976  ASOKNGR
# 6        A02415            PRBTI         PPU NO SIRNMI   01/01/198  ASOKNGR
# 7      A0232121          RMPI BI             MHIPL BIG  01/01/1989    UMRIA
# 8        A02387             SNTI            KRN ADIWSI  01/01/1967   GWLIOR
#
#      Block    Village Cast   RefKey_of_Beneficiaries  \
# 1   AMRPUR     RMPURI   ST                  0.000000
# 3  ASOKNGR   BONSLIGO   ST 287993394052219936.000000
# 4   GTIGON    UMIDGRH   ST                  0.000000
# 5  ASOKNGR  BONSLIGON   ST 556960043973309824.000000
# 6  ASOKNGR  BONSLIGON   ST 245654937535116192.000000
# ...

# %% [markdown]
# Given: The system is expected to run the above processes for all fields such as mobile number, name, last name, Government issued identity numbers, Date of birth, age, email id, income, gender, etc. to ensure adherence to standard formats and a logical citizen profile is created.

# %%
selected_AahaarAnudan_df['RefKey_of_Beneficiaries']=selected_AahaarAnudan_df['RefKey_of_Beneficiaries'].astype("int64")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\3417284192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_AahaarAnudan_df['RefKey_of_Beneficiaries']=selected_AahaarAnudan_df['RefKey_of_Beneficiaries'].astype("int64")

# %% [markdown]
# ## Comparing the reference dataframes over here

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name    Father/HusbandName DateOFBirth District  \
# 1       A038674           SZN BI                  BNWR  01/01/1979  DINDORI
# 3        A06254             MNGO        COT NO SIRNIMI  03/04/1975  ASOKNGR
# 4      A0216038            BGWTI          TULRM ADIWSI  01/01/1985   GWLIOR
# 5        A02410             MUNI  RNWIR SING NO SIRNMI  01/01/1976  ASOKNGR
# 6        A02415            PRBTI         PPU NO SIRNMI   01/01/198  ASOKNGR
# 7      A0232121          RMPI BI             MHIPL BIG  01/01/1989    UMRIA
# 8        A02387             SNTI            KRN ADIWSI  01/01/1967   GWLIOR
#
#      Block    Village Cast  RefKey_of_Beneficiaries  \
# 1   AMRPUR     RMPURI   ST                        0
# 3  ASOKNGR   BONSLIGO   ST       287993394052219936
# 4   GTIGON    UMIDGRH   ST                        0
# 5  ASOKNGR  BONSLIGON   ST       556960043973309824
# 6  ASOKNGR  BONSLIGON   ST       245654937535116192
# ...

# %%
selected_AahaarAnudan_df_initial
# Out:
#   ApplicationID Beneficiary_Name        Father/HusbandName  \
# 0    AA00004493        Tersi bai                       NaN
# 1    AA00038674        SAJAN BAI              W/O: Bhanwar
# 2    AA00039668            BUNDI                 FUL SINGH
# 3    AA00062254           Mango           Chota No Sirneme
# 4    AA00216038        BHAGVATI            Tularam Adivasi
# 5    AA00224410            MUNNI  Ranveer Singh No Sirname
# 6    AA00224415          PARBATI          Pappu No Siranme
# 7    AA00232121        Rampi Bai             Mahipal Baiga
# 8    AA00233877           SHANTI             Karan Adiwasi
# 9    AA00240399    REENA ADIVASI             VIJAY ADIWASI
#
#                DateOFBirth    District       Block         Village Cast  \
# 0  1988-01-01 00:00:00.000      Umaria        Pali             NaN   ST
# 1  1979-01-01 00:00:00.000     Dindori     Amarpur         RAMPURI   ST
# 2  1985-01-05 00:00:00.000     Dindori     Amarpur         Rampuri  NaN
# ...

# %%
AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name        Father/HusbandName  \
# 0    AA00004493        Tersi bai                       NaN
# 1    AA00038674        SAJAN BAI              W/O: Bhanwar
# 2    AA00039668            BUNDI                 FUL SINGH
# 3    AA00062254           Mango           Chota No Sirneme
# 4    AA00216038        BHAGVATI            Tularam Adivasi
# 5    AA00224410            MUNNI  Ranveer Singh No Sirname
# 6    AA00224415          PARBATI          Pappu No Siranme
# 7    AA00232121        Rampi Bai             Mahipal Baiga
# 8    AA00233877           SHANTI             Karan Adiwasi
# 9    AA00240399    REENA ADIVASI             VIJAY ADIWASI
#
#                DateOFBirth    District       Block              GP  \
# 0  1988-01-01 00:00:00.000      Umaria        Pali          Gijari
# 1  1979-01-01 00:00:00.000     Dindori     Amarpur         RAMPURI
# 2  1985-01-05 00:00:00.000     Dindori     Amarpur         RAMPURI
# ...

# %%
columns_to_clean
# Out:
# ['Beneficiary_Name',
#  'Father/HusbandName',
#  'District',
#  'Block',
#  'Village',
#  'Cast']

# %%
selected_AahaarAnudan_df
# Out:
#   ApplicationID Beneficiary_Name    Father/HusbandName DateOFBirth District  \
# 1       A038674           SZN BI                  BNWR  01/01/1979  DINDORI
# 3        A06254             MNGO        COT NO SIRNIMI  03/04/1975  ASOKNGR
# 4      A0216038            BGWTI          TULRM ADIWSI  01/01/1985   GWLIOR
# 5        A02410             MUNI  RNWIR SING NO SIRNMI  01/01/1976  ASOKNGR
# 6        A02415            PRBTI         PPU NO SIRNMI   01/01/198  ASOKNGR
# 7      A0232121          RMPI BI             MHIPL BIG  01/01/1989    UMRIA
# 8        A02387             SNTI            KRN ADIWSI  01/01/1967   GWLIOR
#
#      Block    Village Cast  RefKey_of_Beneficiaries  \
# 1   AMRPUR     RMPURI   ST                        0
# 3  ASOKNGR   BONSLIGO   ST       287993394052219936
# 4   GTIGON    UMIDGRH   ST                        0
# 5  ASOKNGR  BONSLIGON   ST       556960043973309824
# 6  ASOKNGR  BONSLIGON   ST       245654937535116192
# ...

# %%
import csv
from fuzzywuzzy import fuzz

# Function to read data from CSV file
def read_data_from_csv(file_path):
    data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

# Sample source data CSV file path
source_csv_path = '../data/Tables-Sampledata/Ayusman.csv'

# Sample reference data CSV file path
reference_csv_path = '../data/Tables-Sampledata/AahaarAnudan.csv'

# Read data from CSV files
source_data = read_data_from_csv(source_csv_path)
reference_data = read_data_from_csv(reference_csv_path)

# %%
source_data[5]
# Out:
# {'\ufeffahl_tin': '101237353',
#  'ahl_hhid': '20293387',
#  'name_ben': 'LAXMI CHAND REGAR',
#  'father_name_secc': 'PANNA LAL REGAR',
#  'mother_name_secc': 'PARA BAI REGAR',
#  'dob_ben': '1976',
#  'gender_ben': 'M',
#  'district_code': '431',
#  'village_code': '114381',
#  'ward_code': 'NULL',
#  'rural_urban': 'U',
#  'pmrssm_id': 'PN6Z02QMT',
#  'updateddate': '2019-01-27 20:38:00',
#  'matched_Samagra': '3',
#  'DePtID': '1126',
#  'SchemeID': '81'}

# %%
reference_data[5]
# Out:
# {'\ufeffApplicationID': 'AA00224410',
#  'Beneficiary_Name': 'MUNNI',
#  'Father/HusbandName': 'Ranveer Singh No Sirname',
#  'DateOFBirth': '1976-01-01 00:00:00.000',
#  'District': 'Ashoknagar',
#  'Block': 'Ashoknagar',
#  'GP': 'SADUMARA',
#  'Village': 'BHONSLEGAON',
#  'Cast': 'ST',
#  'SubCaste': 'Sahariya',
#  'SamagraID': '100315152',
#  'SamagraFamilyID': '20061739',
#  'eEKYC_Status': 'Yes',
#  'Profile_Status': 'Active',
#  'eKYC_Date': '2023-04-21 15:20:00.000',
#  'Project_status': 'NULL',
#  'DOB': '1976-01-01',
#  'Gender': 'Female',
#  'RefKey_of_Beneficiaries': '556960043973309834',
#  'Aadhaar_Anudaan_Registration_Date': '2020-12-30 13:25:12.187',
#  'Insert_Date_Time': 'NULL',
#  'DePtID': '24',
#  'SchemeID': '33',
#  'Active': 'NULL',
#  'Remark': 'NULL'}

# %%
# Function to perform fuzzy matching
def fuzzy_match_records(source_record, reference_records, threshold=70):
    matches = []
    for ref_record in reference_records:
        name_similarity = fuzz.token_sort_ratio(source_record["name_ben"], ref_record["Beneficiary_Name"])
        if name_similarity >= threshold:
            matches.append((source_record, ref_record, name_similarity))
    return matches

# Perform fuzzy matching
matches = []
for source_record in source_data:
    matches.extend(fuzzy_match_records(source_record, reference_data))

# Print matched records
for match in matches:
    print("Source:", match[0])
    print("Reference:", match[1])
    print("Name Similarity:", match[2])
    print()
# Out:
# Source: {'\ufeffahl_tin': '101777519', 'ahl_hhid': '20426229', 'name_ben': 'Sanjaya Bai', 'father_name_secc': 'RANJEET BALMIK', 'mother_name_secc': '', 'dob_ben': '1988', 'gender_ben': 'F', 'district_code': '431', 'village_code': '114392', 'ward_code': 'NULL', 'rural_urban': 'U', 'pmrssm_id': 'PANY03NLS', 'updateddate': '2019-03-02 06:44:00', 'matched_Samagra': '3', 'DePtID': '1126', 'SchemeID': '81'}
# ...

# %%
import csv
import pandas as pd
from fuzzywuzzy import fuzz

# Function to read data from CSV file
def read_data_from_csv(file_path):
    data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

# Sample source data CSV file path
source_csv_path = '../data/Tables-Sampledata/Ayusman.csv'

# Sample reference data CSV file path
reference_csv_path = '../data/Tables-Sampledata/AahaarAnudan.csv'

# Read data from CSV files
source_data = read_data_from_csv(source_csv_path)
reference_data = read_data_from_csv(reference_csv_path)

# Function to perform fuzzy matching
def fuzzy_match_records(source_record, reference_records, threshold=70):
    matches = []
    for ref_record in reference_records:
        name_similarity = fuzz.token_sort_ratio(source_record["name_ben"], ref_record["Beneficiary_Name"])
        if name_similarity >= threshold:
            matches.append({
                'BaseData': source_record,
                'ReferenceData': ref_record,
                'NameSimilarity': name_similarity
            })
    return matches

# Perform fuzzy matching
matches = []
for source_record in source_data:
    matches.extend(fuzzy_match_records(source_record, reference_data))

# Convert matched results to pandas DataFrame
matched_df = pd.DataFrame(matches)

# Save matched results to CSV
matched_df.to_csv('matched_results.csv', index=False)

# Print matched records
for index, match in matched_df.iterrows():
    print("Base Data:")
    print(match['BaseData'])
    print("Reference Data:")
    print(match['ReferenceData'])
    print("Name Similarity:", match['NameSimilarity'])
    print()
# Out:
# Base Data:
# {'\ufeffahl_tin': '101777519', 'ahl_hhid': '20426229', 'name_ben': 'Sanjaya Bai', 'father_name_secc': 'RANJEET BALMIK', 'mother_name_secc': '', 'dob_ben': '1988', 'gender_ben': 'F', 'district_code': '431', 'village_code': '114392', 'ward_code': 'NULL', 'rural_urban': 'U', 'pmrssm_id': 'PANY03NLS', 'updateddate': '2019-03-02 06:44:00', 'matched_Samagra': '3', 'DePtID': '1126', 'SchemeID': '81'}
# Reference Data:
# ...

# %% [markdown]
# ## Ratcliff/Obershelp Pattern Recognition algorithm (‘SequenceMatcher’)

# %%
import csv
import pandas as pd
from difflib import SequenceMatcher

# Function to read data from CSV file
def read_data_from_csv(file_path):
    data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

# Sample source data CSV file path
source_csv_path = '../data/Tables-Sampledata/Ayusman.csv'

# Sample reference data CSV file path
reference_csv_path = '../data/Tables-Sampledata/AahaarAnudan.csv'

# Read data from CSV files
source_data = read_data_from_csv(source_csv_path)
reference_data = read_data_from_csv(reference_csv_path)

# Function to perform fuzzy matching using SequenceMatcher
def sequence_match_records(source_record, reference_records, threshold=0.6):
    matches = []
    for ref_record in reference_records:
        name_similarity = SequenceMatcher(None, source_record["name_ben"], ref_record["Beneficiary_Name"]).ratio()
        if name_similarity >= threshold:
            matches.append({
                'BaseData': source_record,
                'ReferenceData': ref_record,
                'NameSimilarity': name_similarity
            })
    return matches

# Perform fuzzy matching using SequenceMatcher
matches = []
for source_record in source_data:
    matches.extend(sequence_match_records(source_record, reference_data))

# Convert matched results to pandas DataFrame
matched_df = pd.DataFrame(matches)

# Save matched results to CSV
matched_df.to_csv('matched_results_sequence_matcher.csv', index=False)

# Print matched records
for index, match in matched_df.iterrows():
    print("Base Data:")
    print(match['BaseData'])
    print("Reference Data:")
    print(match['ReferenceData'])
    print("Name Similarity:", match['NameSimilarity'])
    print()
# Out:
# Base Data:
# {'\ufeffahl_tin': '101479790', 'ahl_hhid': '20352037', 'name_ben': 'Ramkesh Bairwa', 'father_name_secc': 'BABU LAL', 'mother_name_secc': 'PRASADI BAI', 'dob_ben': '1985', 'gender_ben': 'M', 'district_code': '431', 'village_code': '107808', 'ward_code': 'NULL', 'rural_urban': 'R', 'pmrssm_id': 'PMQVEFY51', 'updateddate': '2019-02-27 17:32:00', 'matched_Samagra': '1', 'DePtID': '1126', 'SchemeID': '81'}
# Reference Data:
# ...

# %% [markdown]
# ## Levenshtein algorithm (‘FuzzyWuzzy’)

# %%
import csv
import pandas as pd
from fuzzywuzzy import fuzz

# Function to read data from CSV file
def read_data_from_csv(file_path):
    data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

# Sample source data CSV file path
source_csv_path = '../data/Tables-Sampledata/Ayusman.csv'

# Sample reference data CSV file path
reference_csv_path = '../data/Tables-Sampledata/AahaarAnudan.csv'

# Read data from CSV files
source_data = read_data_from_csv(source_csv_path)
reference_data = read_data_from_csv(reference_csv_path)

# Function to perform fuzzy matching using Levenshtein algorithm
def levenshtein_match_records(source_record, reference_records, threshold=60):
    matches = []
    for ref_record in reference_records:
        name_similarity = fuzz.ratio(source_record["name_ben"], ref_record["Beneficiary_Name"])
        if name_similarity >= threshold:
            matches.append({
                'BaseData': source_record,
                'ReferenceData': ref_record,
                'NameSimilarity': name_similarity
            })
    return matches

# Perform fuzzy matching using Levenshtein algorithm
matches = []
for source_record in source_data:
    matches.extend(levenshtein_match_records(source_record, reference_data))

# Convert matched results to pandas DataFrame
matched_df = pd.DataFrame(matches)

# Save matched results to CSV
matched_df.to_csv('matched_results_levenshtein.csv', index=False)

# Print matched records
for index, match in matched_df.iterrows():
    print("Base Data:")
    print(match['BaseData'])
    print("Reference Data:")
    print(match['ReferenceData'])
    print("Name Similarity:", match['NameSimilarity'])
    print()
# Out:
# Base Data:
# {'\ufeffahl_tin': '101479790', 'ahl_hhid': '20352037', 'name_ben': 'Ramkesh Bairwa', 'father_name_secc': 'BABU LAL', 'mother_name_secc': 'PRASADI BAI', 'dob_ben': '1985', 'gender_ben': 'M', 'district_code': '431', 'village_code': '107808', 'ward_code': 'NULL', 'rural_urban': 'R', 'pmrssm_id': 'PMQVEFY51', 'updateddate': '2019-02-27 17:32:00', 'matched_Samagra': '1', 'DePtID': '1126', 'SchemeID': '81'}
# Reference Data:
# ...

# %%
import csv
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Function to read data from CSV file
def read_data_from_csv(file_path):
    data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

# Sample source data CSV file path
source_csv_path = '../data/Tables-Sampledata/Ayusman.csv'

# Sample reference data CSV file path
reference_csv_path = '../data/Tables-Sampledata/AahaarAnudan.csv'

# Read data from CSV files
source_data = read_data_from_csv(source_csv_path)
reference_data = read_data_from_csv(reference_csv_path)

# Function to perform fuzzy matching using Jaccard similarity
def jaccard_match_records(source_record, reference_records, threshold=0.3):
    matches = []
    source_name_tokens = set(source_record["name_ben"].split())
    for ref_record in reference_records:
        ref_name_tokens = set(ref_record["Beneficiary_Name"].split())
        jaccard_similarity = len(source_name_tokens.intersection(ref_name_tokens)) / len(source_name_tokens.union(ref_name_tokens))
        if jaccard_similarity >= threshold:
            matches.append({
                'BaseData': source_record,
                'ReferenceData': ref_record,
                'NameSimilarity': jaccard_similarity
            })
    return matches

# Perform fuzzy matching using Jaccard similarity
matches = []
for source_record in source_data:
    matches.extend(jaccard_match_records(source_record, reference_data))

# Convert matched results to pandas DataFrame
matched_df = pd.DataFrame(matches)

# Save matched results to CSV
matched_df.to_csv('matched_results_jaccard.csv', index=False)

# Print matched records
for index, match in matched_df.iterrows():
    print("Base Data:")
    print(match['BaseData'])
    print("Reference Data:")
    print(match['ReferenceData'])
    print("Name Similarity:", match['NameSimilarity'])
    print()
# Out:
# Base Data:
# {'\ufeffahl_tin': '101777519', 'ahl_hhid': '20426229', 'name_ben': 'Sanjaya Bai', 'father_name_secc': 'RANJEET BALMIK', 'mother_name_secc': '', 'dob_ben': '1988', 'gender_ben': 'F', 'district_code': '431', 'village_code': '114392', 'ward_code': 'NULL', 'rural_urban': 'U', 'pmrssm_id': 'PANY03NLS', 'updateddate': '2019-03-02 06:44:00', 'matched_Samagra': '3', 'DePtID': '1126', 'SchemeID': '81'}
# Reference Data:
# ...

# %%
# Master + Family combined
# Preprocessing
# run

# %%
import csv
import pandas as pd
from fuzzywuzzy import fuzz

# Function to read data from CSV file
def read_data_from_csv(file_path):
    data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

# Sample source data CSV file path
source_csv_path = '../data/Tables-Sampledata/Family_Member.csv'

# Sample reference data CSV file path
reference_csv_path = '../research/ReferenceData.csv'

# Read data from CSV files
source_data = read_data_from_csv(source_csv_path)
reference_data = read_data_from_csv(reference_csv_path)

# Function to perform fuzzy matching
def fuzzy_match_records(source_record, reference_records, threshold=70):
    matches = []
    for ref_record in reference_records:
        name_similarity = fuzz.token_sort_ratio(source_record["FullNameEn"], ref_record["FullNameEn"])
        if name_similarity >= threshold:
            matches.append({
                'BaseData': source_record,
                'ReferenceData': ref_record,
                'NameSimilarity': name_similarity
            })
    return matches

# Perform fuzzy matching
matches = []
for source_record in source_data:
    matches.extend(fuzzy_match_records(source_record, reference_data))

# Convert matched results to pandas DataFrame
matched_df = pd.DataFrame(matches)

# Save matched results to CSV
matched_df.to_csv('matched_results.csv', index=False)

# Print matched records
for index, match in matched_df.iterrows():
    print("Base Data:")
    print(match['BaseData'])
    print("Reference Data:")
    print(match['ReferenceData'])
    print("Name Similarity:", match['NameSimilarity'])
    print()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
Ayusman_df=pd.read_csv("Tables/Ayusman.csv",low_memory=False)

# %%
Ayusman_df.head(2)
# Out:
#      ahl_tin  ahl_hhid            name_ben father_name_secc mother_name_secc  \
# 0  101468621  20349094       Yogesh Batham              NaN              NaN
# 1  101452057  20345657  Hari Shankar Suman              NaN              NaN
#
#    dob_ben gender_ben  district_code  village_code  ward_code rural_urban  \
# 0     2013          M            431        114381        NaN           U
# 1     1992          M            431        114381        NaN           U
#
#    pmrssm_id          updateddate  matched_Samagra  DePtID  SchemeID
# 0  PHQX0Y0ZU  2020-12-27 22:38:00                3    1126        81
# 1  PE6M4SP87  2020-12-27 22:02:00                1    1126        81

# %%
Ayusman_df.columns
# Out:
# Index(['ahl_tin', 'ahl_hhid', 'name_ben', 'father_name_secc',
#        'mother_name_secc', 'dob_ben', 'gender_ben', 'district_code',
#        'village_code', 'ward_code', 'rural_urban', 'pmrssm_id', 'updateddate',
#        'matched_Samagra', 'DePtID', 'SchemeID'],
#       dtype='object')

# %%
Ayusman_df['name_ben'].unique()
# Out:
# array(['Yogesh Batham', 'Hari Shankar Suman', 'Kelash',
#        'Hukum Chand Garg', 'Ranajit', 'LAXMI CHAND REGAR',
#        'Ramchrat Bairwa', 'Ashok Balmik', 'Sorabh', 'Mukesh',
#        'Ramkesh Bairwa', 'Durga Shankar Lodha', 'Vishal',
#        'Nandkishor Batham', 'Pawan Prajapati', 'Sonu Balmik',
#        'Chintu Regar', 'Hariom Suman', 'Kamal Kishor Chawda',
#        'Vikash Balmik', 'Mahendra Bairwa', 'Rahul Mahour', 'Monu Raigar',
#        'Mangilal Suman', 'Pinki', 'Tulaseeram Prajapati', 'Ravi Regar',
#        'Yogesh Kumar Saini', 'Dinesh Batham', 'Kapil', 'DEVENDRA BAGHAL',
#        'Prabhulal Berva', 'Ramesh Chand', 'JAYANT SAINI',
#        'Bramhadev Jatav', 'Shyam Singh Rathor', 'Aasharam', 'Mamta',
#        'Maya Devi Saini', 'Roshan Ansari', 'Najma', 'Vijay Prajapati',
#        'Pawan', 'Kaadu', 'Brajmohan Regar', 'Priti Gurjar', 'Mamta Suman',
#        'Sanjaya Bai', 'Shanti Bai Lodha', 'Neha Rajak', 'Brajmohan',
# ...

# %%
Cast_df=pd.read_csv("Tables/Cast.csv",low_memory=False)

# %%
Cast_df.head(2)
# Out:
#    C_Id  Request_Id  Samagra_ID                 Reg_No    Certificate_issue  \
# 0     1         NaN   100000982  RS/449/0118/6154/2019  2019-10-25 13:14:00
# 1  2994         NaN   101964554  RS/418/0106/2289/2021  2021-08-24 12:00:00
#
#         Name_H        Name_E        FName_H          FName_E      MName_H  \
# 0       शिवानी       SHIVANI       मोतीलाल           MOTILAL    गंंगा बाई
# 1  रोनक अंसारी  RONAK ANSARI  मोहम्‍मद आमीन  MOHAMMAD ANSARI  नजमा अंसारी
#
#         MName_E Category_E Category_H  Caste_Code_in_State_List Caste_Name_H  \
# 0     GANGA BAI        OBC        NaN                       NaN          NaN
# 1  NAJMA ANSARI        OBC        NaN                       NaN          NaN
#
#    Caste_Code_in_Centre_List Caste_Name_E Migration_Case CertUrl Insert_Date  \
# 0                        NaN          NaN            NaN     NaN         NaN
# 1                        NaN          NaN            NaN     NaN         NaN
#
# ...

# %%
Cast_df['Name_E'].unique()
# Out:
# array(['SHIVANI', 'RONAK ANSARI', 'SHIVANI MEENA', 'NEHA ', 'TANSHKA ',
#        'NEESHU LODHA ', 'MOHIT LODHA', 'MAHIMA LODHA', 'INDU HINONIYA',
#        'MANEESH IRAJAPAT', 'VIKASH MEENA', 'MILAN MEENA', 'RACHNA LODHA ',
#        'NIKHILSWARNKAR', 'YASMEEN RAHI', 'RIMPI  BAI ', 'BADAL BALMIK ',
#        'RAMCHARAT BAIRWA', 'ANKITRAJ BALMIK', 'DEVRAJ BALMIK',
#        'RAJU JATAV', 'MANOJ KUMAR KASHYAP ', 'DEEPAK JATAV ',
#        'RAJNI BALMIK', 'NISHA JASUNA', 'KAPIL REGAR', 'SAVITA VALMIKI',
#        'BARKHA', 'NILAM BALMIK', 'ANIKITA KUMARI', 'kartik bairwa',
#        'NIKITA VALMIKI', 'DEVRAAJ VALMIKI', 'SURESH SEINGAR',
#        'RAHUL REGAR', 'DIVYANCE MEENA'], dtype=object)

# %%
CM_KIssan_df=pd.read_csv("Tables/CM KIssan.csv",low_memory=False)

# %%
CM_KIssan_df.head(2)
# Out:
#   ApplicantName  SamagraId        RegNo SchemName  SchemType  Amount  \
# 0       AMARLAL  101521986  MP262835324   CMKisan  Recurring    2000
# 1  MUKESH JATAV  101792941  MP262848149   CMKisan  Recurring    2000
#
#   DateofBenefit
# 0    15-05-2022
# 1    16-05-2022

# %%
CM_KIssan_df.shape
# Out:
# (2, 7)

# %%
CM_KIssan_df['ApplicantName'].unique()
# Out:
# array(['AMARLAL', 'MUKESH JATAV'], dtype=object)

# %%
Domicile_df=pd.read_csv("Tables/Domicile.csv",low_memory=False)

# %%
Domicile_df.head(2)
# Out:
#     D_Id  Request_Id  Samagra_ID          Certificate_No Certificate_issue  \
# 0  73256         NaN   101535322  RS/418/0110/10622/2019  05-12-2019 22:14
# 1  74506         NaN   101179490   RS/418/0110/4794/2019  08-07-2019 18:28
#
#                 Name           FName_H  District_Name_E District_Name_H  \
# 0    BARJMOHAN REGAR  CHATURBHUJ REGAR              NaN         श्योपुर
# 1  CHEETAR LAL REGAR   NENAK RAM REGAR              NaN         श्योपुर
#
#   CertUrl Insert_Date  WName  Child_Name  Child_Age Cancel_Flag  \
# 0     NaN         NaN    NaN         NaN        NaN         NaN
# 1     NaN         NaN    NaN         NaN        NaN         NaN
#
#    Request_Member_Id  Verify_By  Identified  DePtID  SchemeID
# 0                NaN        NaN         NaN     NaN       NaN
# 1                NaN        NaN         NaN     NaN       NaN

# %%
Domicile_df['Name'].unique()
# Out:
# array(['BARJMOHAN REGAR', 'CHEETAR LAL REGAR', 'SANGEETA REGAR',
#        'RAMSWARUP JATAV', 'KAPIL', 'भागवती', 'SUDHA REAGR',
#        'अमर सिंह जाटव', 'पुष्पराज सिंह सिकरवार', 'नीरज अटल', 'भवेश अटल',
#        'कुसुम अटल', 'शिशुपाल जाटव', 'कमलेश कुमार सिंघल', 'सुरेश सेंगर',
#        'सुग्रीव गुर्जर', 'राजू जाटव', 'Shivani Yadav', 'राजीव सरल',
#        'Rimpi Bai'], dtype=object)

# %%
Family_df=pd.read_csv("Tables/Family.csv",low_memory=False)

# %%
Family_df.head()
# Out:
#    100560904  district_id  Temporary_ID  village_ward_id  Gadna_Block_ID  \
# 0   20000184           37      0.000000            97900        1.000000
# 1   20002659           34      0.000000           121529       10.000000
# 2   20002694           23      0.000000            82484      234.000000
# 3   20002862           23      0.000000            82204      160.000000
# 4   20002907           23      0.000000            82205      161.000000
#
#   Sub_GB_No  House_No House_Sub_No  House_No_Section    House_Address  \
# 0       NaN       189            A               NaN              NaN
# 1         0       664            0          0.000000              NaN
# 2         0       172            0          1.000000              NaN
# 3         0         5            0          0.000000  Vijaygar Murmya
# 4         0        13            0          0.000000        Sunderpur
#
#   house_hold_number  npr_family_code  pin_code  member_count  \
# ...

# %%
Family_df.columns
# Out:
# Index(['100560904', 'district_id', 'Temporary_ID', 'village_ward_id',
#        'Gadna_Block_ID', 'Sub_GB_No', 'House_No', 'House_Sub_No',
#        'House_No_Section', 'House_Address', 'house_hold_number',
#        'npr_family_code', 'pin_code', 'member_count', 'head_family_member_id',
#        'category_id', 'Category_Code', 'st_ptg_id', 'is_sc_bb',
#        'is_sc_insanitory_works', 'is_vimukt', 'is_minority', 'religion_id',
#        'is_migrated', 'migration_reason_id', 'nominee_family_member_id',
#        'is_native_of_MP', 'year_since_mp_resident', 'is_BPL', 'BPL_Survey_No',
#        'BPL_Survey_Year', 'Toilet_Status', 'Is_Water_Available',
#        'House_Status', 'Property_tax_SNO', 'Water_tax_SNO', 'Nigam_License_No',
#        'Is_Tenant', 'is_locked', 'is_verified', 'is_deleted', 'insert_time',
#        'insert_by_user_id', 'import_phase', 'Varified_By', 'Varified_On',
#        'head_family_member_name', 'FPS_Id', 'is_move', 'is_updated',
# ...

# %%
Family_Member_df=pd.read_csv("Tables/Family_Member.csv",low_memory=False)

# %%
Family_Member_df.head(2)
# Out:
#           id  district_id  Temporary_ID  family_id  village_ward_id  \
# 0  100686666            1        686666   30117241           107579
# 1  101094169            1       1094169   20257923           107874
#
#   Voter_List_Number  NPR_member_code  samagra_code      first_name  \
# 0               NaN              NaN           NaN          Barsha
# 1               NaN              NaN           NaN  Deleted-Gurnam
#
#        last_name first_name_Hi last_name_Hi  is_head  gender_id         dob  \
# 0          Rajak         बर्शा          रजक        0          2  2001-01-01
# 1  Singh Bairagi        गुरनाम  सिंह बैरागी        0          1  1948-01-01
#
#    relation_id  marital_status_id  father_id  mother_id        spouse_id  \
# 0            4                  2          0  141513241 141518229.000000
# 1            0                  2          0          0              NaN
#
#   father_name   mother_name spouse_name  mobile_number  email_address  \
# ...

# %%
Family_Member_df['first_name'].unique()
# Out:
# array(['Barsha', 'Deleted-Gurnam', 'Shambhoo Singh', 'SUGREEV', 'jamila',
#        'Durga Shankar', 'Nathu Lal', 'AJIT', 'VIJAY', 'Kalavti Bai',
#        'Manbhar Bai', 'Seema Bai', 'Banvari', 'Chhitar Lal', 'Mukesh',
#        'Arti Bai', 'Ashok', 'Prkash', 'Devki Bai', 'Ram Singh',
#        'Mahaveer', 'Kadu', 'SHIVANI', 'Ajay', 'Vicky', 'Banti', 'Anita',
#        'Jitendra', 'RAJNI', 'Dheeraj', 'Ramesh', 'Dinesh', 'Ravi',
#        'HANUMAN', 'Vishnu', 'Ram Kawri Bai', 'Laxmi Chand', 'MONU',
#        'CHINTU', 'Priyanka', 'Sone', 'RAHUL', 'NITU', 'Saniya',
#        'PARMANAND', 'Madhu', 'Layak Ram', 'Prabha', 'prateek', 'Punam',
#        'Yogesh Kumar', 'Rinku', 'Pankaj', 'Bhavna', 'Sourabh',
#        'Sambhu Lal', 'Mahendra', 'Chandu Bai', 'Bharat', 'Laxmi',
#        'Suresh', 'Rajni Bai', 'Shivani', 'Mona', 'Murli', 'Manvar',
#        'Uday', 'Aayush', 'Rahul', 'DEEPU', 'Bheru Lal', 'Mahesh', 'Puran',
#        'Suraj', 'GOLU', 'MILAN', 'VIKAS', 'Purshottam', 'Ramsroop',
# ...

# %%
Family_Member_df['last_name'].unique()
# Out:
# array(['Rajak', 'Singh Bairagi', 'Gurjar', 'GURJAR', 'saify', 'Regar',
#        'REGAR', 'Mali', 'Meena', 'Batham', 'MEENA', 'BATHAM', 'PARIHAR',
#        'Baghel', 'Baghal', 'pal', 'Rawat', 'kare', 'Rathor', 'RATHOR',
#        'batham', 'YADAV', 'Berwa', 'Jatav', 'Bairwa', 'Jatva',
#        'Prajapati', 'PRAJAPATI', 'Suman', 'JATAV', 'Bai', 'Mahor',
#        'Maahor', 'Maali', 'MAALI', 'Prjapati', 'Sharma', 'Bairva',
#        'BAIRAWA', 'BANO', 'MAAHOR', 'mahor', 'Nath', 'Shivhare', nan,
#        'Mohammad', 'Ahmad', 'Bano', 'Pankaj', 'regar', 'Lodha', 'LODHA',
#        'lodha', 'Lodh', 'BAI', 'bairwa', 'Loudha', 'Berawa', 'LOUDHA',
#        'BAATHAM', 'Swarnkar', 'Cannd', 'SWARNKAR', 'Prjapaty', 'Prajpati',
#        'Pirjapati', 'Mangal', 'Balmike', 'Balmiki', 'Balmik', 'BALMIK',
#        'BALMIKI', 'MAHOOR', 'Garg', 'BERWA', 'Mahoor', 'Logha',
#        'prajapati', 'Jaageen', 'Jageen', 'Jangid', 'Singhal', 'balmik',
# ...

# %%
Family_Member_df['FullNameEn'].unique()
# Out:
# array(['Barsha Rajak', 'Deleted-Gurnam Singh Bairagi',
#        'Shambhoo Singh Gurjar', 'SUGREEV GURJAR', 'jamila saify',
#        'Durga Shankar Regar', 'Nathu Lal Regar', 'AJIT REGAR',
#        'VIJAY REGAR', 'Kalavti Bai Mali', 'Manbhar Bai Mali',
#        'Seema Bai Mali', 'Banvari Meena', 'Chhitar Lal Regar',
#        'Mukesh Meena', 'Arti Bai Meena', 'Ashok Meena', 'Prkash Mali',
#        'Devki Bai Meena', 'Ram Singh Meena', 'Mahaveer Meena',
#        'Kadu Batham', 'SHIVANI MEENA', 'Ajay Batham', 'Vicky Batham',
#        'Banti Batham', 'Anita Batham', 'Jitendra Meena', 'RAJNI BATHAM',
#        'Dheeraj Batham', 'Ramesh Regar', 'Dinesh Regar', 'Ravi Regar',
#        'HANUMAN MEENA', 'Vishnu Regar', 'Ram Kawri Bai Regar',
#        'Laxmi Chand Regar', 'Mukesh Regar', 'MONU REGAR', 'CHINTU REGAR',
#        'Priyanka Regar', 'Dinesh Batham', 'Sone Batham', 'RAHUL BATHAM',
#        'NITU PARIHAR', 'Saniya Batham', 'PARMANAND REGAR', 'Madhu Regar',
# ...

# %%
Income_df=pd.read_csv("Tables/Income.csv",low_memory=False)

# %%
Income_df.head(2)
# Out:
#     I_Id  Request_Id  Samagra_ID         Certificate_No    Certificate_issue  \
# 0  14833         NaN   101342716   RS/418/0111/433/2022  2022-01-27 00:00:00
# 1  36333         NaN   101457852  RS/429/0111/5205/2022  2022-02-04 00:00:00
#
#                 Name          FName_H  \
# 0   पुरुषोत्तम राठोर          Narayan
# 1  सुजीत कुमार दहायत  कुशमय लाल दहायत
#
#                                              Address  Annual_Income  \
# 0  WARD NO 05 BADI THODI BARODA,mahatma gandhi wa...          40000
# 1                             हडहा,Hadaha,Nagod,सतना          30000
#
#   District_Name_E District_Name_h  \
# 0         Sheopur         श्योपुर
# 1           Satna            सतना
#
#                                              CertUrl              Insert_Date  \
# 0  http://mpedistrict.gov.in/Public/ViewCertifica...  2022-01-27 17:42:08.643
# 1  http://mpedistrict.gov.in/Public/ViewCertifica...  2022-02-04 23:19:12.297
#
# ...

# %%
Income_df['CertUrl'][0]
# Out:
# 'http://mpedistrict.gov.in/Public/ViewCertificateSP_Public.aspx?param=73ZM+fRIf0zF55pPaqM65DaR8lOB/knmazy+8NCTSJc='

# %%
Income_df['Name'].unique()
# Out:
# array(['पुरुषोत्तम राठोर', 'सुजीत कुमार दहायत', 'अमर सिंह जाटव',
#        'सन्त सिंह अटल', 'मुकेश जाटव', 'शिशुपाल जाटव', 'कमलेश कुमार सिंघल',
#        'हरिओम बाल्मिकी', 'पूजा सोलंकी', 'सुग्रीव गुर्जर',
#        'HARIOM KUSHWAH', 'भागवती', 'पूरण रेगर'], dtype=object)

# %%
lby_df=pd.read_csv("Tables/lby.csv",low_memory=False)

# %%
lby_df.head(2)
# Out:
#    BeneficiaryID  FamilySamagra_ID  Samagra_ID Applicant_Name         DOB  \
# 0       10984943          49331534   135797215  Varsha Bairwa  1997-06-01
# 1       11886776          20158538   100667821      Mango Bai  1963-01-01
#
#   Gender Caste HeadFamilyMemberName  RelationCode    MobileNo  \
# 0      F    SC          Vivek Jatav             2  9691157211
# 1      F    ST       Chhota Adiwasi             2  6267223226
#
#    Alternet_MobileNumber        WhatsUpMob                    RefKey  \
# 0      9691157211.000000 9691157211.000000 920356819014541568.000000
# 1                    NaN               NaN 287993394052219968.000000
#
#    Pension_Beneficiary  Pension_Type_Id  AadharAndBanklinking_Status  \
# 0                    0              NaN                     1.000000
# 1                    0              NaN                     1.000000
#
#   DBT_Status  DePtID  SchemeID         RegistrationDate  Rec_Status  \
# ...

# %%
lby_df['Applicant_Name'].unique()
# Out:
# array(['Varsha Bairwa', 'Mango Bai', 'Laxmi Ahirwar', 'najma bano',
#        'Suneeta Kushwah', 'Priyanka', 'Soorataya Bhilala', 'Pinki',
#        'Parvati Bai Adibasi', 'Revati Kushawah', 'Bindra Dhakad',
#        'CHANDRAKLA DHAKAD', 'Rachna  Jatav', 'Shivani  Yadav'],
#       dtype=object)

# %%
Mptass_df=pd.read_csv("Tables/Mptass.csv",low_memory=False)

# %%
Mptass_df.head(2)
# Out:
#       uid  DistrictCode DistrictNameEnglish  BlockCode BlockNameEnglish  \
# 0  276536            37             Vidisha 158.000000          Vidisha
# 1  281859            37             Vidisha 158.000000          Vidisha
#
#         adh_name            father_name MPTAASProfileId   samagraMemberID  \
# 0  Rahul Ahirwar          : Chirojiolal     PR1000113542        100002544
# 1  Pooja Ahirwar  : Chironjilal Ahirwar     PR1000154278        100002543
#
#    samagraFamilyID ProfileRegistrationDate          name_E  \
# 0         20003626     2018-07-17 17:08:00  राहुल अहिरवार
# 1         20003626     2018-07-18 12:51:00   पूजा अहिरवार
#
#            father_nameE      mother_nameE                 cert_no  \
# 0   चिरोंजीलाल अहिरवार      सरस्वती  बाई   RS/443/0104/11983/2015
# 1  चिरोंजी लाल अहिरवार   सरस्वती अहिरवार      RS/443/0117/60/2018
#
#   issuance_date     CasteEnglish     CasteHindi    AadhaarReference  \
# 0    2015-05-19  Scheduled Caste  अनुसूचित जाति  662892365230854870
# ...

# %%
Mptass_df['adh_name'].unique()
# Out:
# array(['Rahul Ahirwar', 'Pooja Ahirwar', 'Gaura Ahirwar',
#        'Dharmendra Gehlod', 'Kamal Kishor Chawda', 'Rachana Jatav',
#        'Laxmi Ahirwar', 'Rimpi Bai', 'Harendra Kumar Mahour',
#        'Naresh Bairwa', 'Teena Jatav', 'Sandhya Ahirwar', 'Aakash',
#        'Shivani', 'Shivam'], dtype=object)

# %%
Pension_df=pd.read_csv("Tables/Pension.csv",low_memory=False)

# %%
Pension_df.head(2)
# Out:
#    family_member_id  Pension_Type_id  \
# 0         100196901                1
# 1         100614458                2
#
#                                     pension_type  SchemeID  DePtID
# 0  Indira Gandhi National Old Age Pension Scheme 52.000000      25
# 1     Indra Gandhi National Widow Pension Scheme 53.000000      25

# %%
Sambal_df=pd.read_csv("Tables/Sambal.csv",low_memory=False)

# %%
Sambal_df.head(2)
# Out:
#           id  District_ID   VW_ID  Family_ID first_name last_name Father_Name  \
# 0  101481908            1  114392   20352581     Pooran     Jatav   बद्री लाल
# 1  101481908            1  114392   20352581     Pooran     Jatav   बद्री लाल
#
#    Mobile_number  Gender_ID  Scheme_Id  Sub_Scheme_Id  \
# 0            NaN          1          3              5
# 1            NaN          1         11              6
#
#                         SubSchemes  LB_ID  Family_Member_ID  \
# 0              अंत्येष्टि  सहायता   23352         101481908
# 1  अनुग्रह सहायता (सामान्य मृत्यु)  23352         101481908
#
#        ApplicationDate  Applicant_Name  Amount      Sanctioned_Date
# 0  2020-04-17 00:00:00             NaN    5000  2020-04-17 14:06:00
# 1  2020-04-16 00:00:00             NaN  200000  2020-06-06 15:46:00

# %%
Sambal_df['first_name'].unique()
# Out:
# array(['Pooran', 'Raju', 'Bheru Lal'], dtype=object)

# %%
Sambal_df['last_name'].unique()
# Out:
# array(['Jatav', 'Balmiki'], dtype=object)

# %%
Sambal_df['Full Name']=Sambal_df['first_name'] + " " +Sambal_df['last_name']

# %%
Sambal_df['Full Name'].unique()
# Out:
# array(['Pooran Jatav', 'Raju Balmiki', 'Bheru Lal Jatav'], dtype=object)

# %%
SJED_df=pd.read_csv("Tables/SJED.csv",low_memory=False)

# %%
SJED_df.head(2)
# Out:
#   District Name                    LB Name                   GP/Zone Name  \
# 0       SHEOPUR  Janpad Panchayat, SHEOPUR                      MITHEPURA
# 1        RAISEN     Nagar Parishad, SANCHI  Zone 1, Nagar Parishad Sanchi
#
#    Village/Ward Name  Beneficiary_SamagrID   Beneficiary_Name      DoB  \
# 0             Guwadi             101680464         ARTI BERWA  00:00.0
# 1            ward 10             100002464  LAXMI BAI AHIRVAR  00:00.0
#
#    Beneficiary_Mobile_Number  matched_Samagra                    Scheme_Name  \
# 0          9826226547.000000                1                  Nishakt Vivah
# 1                        NaN                1  मुख्यमंत्री कन्या विवाह योजना
#
#    DePtID  SchemeID
# 0     NaN       NaN
# 1     NaN       NaN

# %%
SJED_df['Beneficiary_Name'].unique()
# Out:
# array(['ARTI BERWA', 'LAXMI BAI AHIRVAR', 'SAVITRI MAAHOR'], dtype=object)

# %%
StreenVendor_df=pd.read_csv("Tables/StreenVendor.csv",low_memory=False)

# %%
StreenVendor_df.head(2)
# Out:
#                         VendorProfileID VendorType           VendorName  \
# 0  15ADCB06-30F2-4333-A036-B0AAEAA96D7A      Urban  Durga Shankar Regar
# 1  99ECF2A3-C498-47AA-A72A-6BF79E5645B3      Urban               Hariom
#
#    SamagraID               CertificateNo          CertificateDate  \
# 0  101164307  SVSHESHE458944542317120935  2020-09-11 00:00:00.000
# 1  101678959  SVSHEBAD220859267533111811  2021-01-12 00:00:00.000
#
#      AadharRefrenceNo         RegistrationDate     ApproverName Designation  \
# 0  458944542317120935  2020-06-23 00:00:00.000         Anil Jha         CMM
# 1  220859267533111811  2021-01-11 00:00:00.000  Harimohan Suman         ARI
#
#   Flag  matched_Dob  Adhar matched Record  Name matched(100%) Record  \
# 0    U          NaN                   NaN                   1.000000
# 1    U          NaN                   NaN                        NaN
#
#    Name matched_percentage  Identified  DePtID  SchemeID
# ...

# %%
StreenVendor_df['VendorName'].unique()
# Out:
# array(['Durga Shankar Regar', 'Hariom', 'Abhishek Ojha', 'Bharat Regar',
#        'Vikram Balmik', 'Rinku Batham', 'Hariom Shivhare',
#        'Mahaveer Bairwa', 'Ashok Rajak', 'Kailash', 'Sonu Balmik',
#        'Tulaseeram Prajapati'], dtype=object)

# %%
# import streamlit as st
# import pandas as pd
# from fuzzywuzzy import fuzz
# from fuzzywuzzy import process

# # Load sample data
# base_data = pd.DataFrame({
#     'Name': ['John Doe', 'Jane Smith', 'Bob Johnson', 'Alice Brown'],
#     'Father Name': ['John Sr.', 'Michael Smith', 'Robert Johnson', 'William Brown'],
#     'Mother Name': ['Mary Doe', 'Elizabeth Smith', 'Susan Johnson', 'Helen Brown'],
#     'Address': ['123 Main St', '456 Elm St', '789 Oak St', '321 Pine St']
# })

# ref_data1 = pd.DataFrame({
#     'Name': ['Jon Doe', 'Jen Smith', 'Bobby Johnson', 'Ally Brown'],
#     'Father Name': ['John Sr.', 'Mike Smith', 'Rob Johnson', 'Will Brown'],
#     'Mother Name': ['Mary Doe', 'Liz Smith', 'Sue Johnson', 'Helen Brown'],
#     'Address': ['123 Main St', '456 Elm St', '789 Oak St', '321 Pine St']
# })

# ref_data2 = pd.DataFrame({
#     'Name': ['Johndoe', 'Janesmith', 'Bobjohnson', 'Alicebrown'],
#     'Father Name': ['John Sr.', 'Michael Smith', 'Robert Johnson', 'William Brown'],
#     'Mother Name': ['Mary Doe', 'Elizabeth Smith', 'Susan Johnson', 'Helen Brown'],
#     'Address': ['123 Main St', '456 Elm St', '789 Oak St', '321 Pine St']
# })

# # Define the Data Triangulation Algorithm
# def data_triangulation(base_data, ref_data1, ref_data2):
#     # Step 1: Ingestion
#     base_data_ingested = base_data.copy()
#     ref_data1_ingested = ref_data1.copy()
#     ref_data2_ingested = ref_data2.copy()

#     # Step 2: Pre-processing
#     base_data_preprocessed = base_data_ingested.apply(lambda x: x.str.strip().str.title())
#     ref_data1_preprocessed = ref_data1_ingested.apply(lambda x: x.str.strip().str.title())
#     ref_data2_preprocessed = ref_data2_ingested.apply(lambda x: x.str.strip().str.title())

#     # Step 3: Multi-dataset matching
#     matches = []
#     for index, row in base_data_preprocessed.iterrows():
#         name_score1 = fuzz.ratio(row['Name'], ref_data1_preprocessed['Name'].iloc[index])
#         father_name_score1 = fuzz.ratio(row['Father Name'], ref_data1_preprocessed['Father Name'].iloc[index])
#         mother_name_score1 = fuzz.ratio(row['Mother Name'], ref_data1_preprocessed['Mother Name'].iloc[index])
#         address_score1 = fuzz.ratio(row['Address'], ref_data1_preprocessed['Address'].iloc[index])

#         name_score2 = fuzz.ratio(row['Name'], ref_data2_preprocessed['Name'].iloc[index])
#         father_name_score2 = fuzz.ratio(row['Father Name'], ref_data2_preprocessed['Father Name'].iloc[index])
#         mother_name_score2 = fuzz.ratio(row['Mother Name'], ref_data2_preprocessed['Mother Name'].iloc[index])
#         address_score2 = fuzz.ratio(row['Address'], ref_data2_preprocessed['Address'].iloc[index])

#         match_score1 = (name_score1 + father_name_score1 + mother_name_score1 + address_score1) / 4
#         match_score2 = (name_score2 + father_name_score2 + mother_name_score2 + address_score2) / 4

#         if match_score1 > match_score2:
#             matches.append((row, ref_data1_preprocessed.iloc[index], match_score1))
#         else:
#             matches.append((row, ref_data2_preprocessed.iloc[index], match_score2))

#     # Step 4: Post-processing
#     matched_data = pd.DataFrame(matches, columns=['Base Data', 'Matched Data', 'Match Score'])

#     return matched_data

# # Create a Streamlit app
# st.title("Data Triangulation Algorithm Demo")

# st.header("Base Data")
# st.write(base_data)

# st.header("Reference Data 1")
# st.write(ref_data1)

# st.header("Reference Data 2")
# st.write(ref_data2)

# st.header("Data Triangulation Results")
# matched_data = data_triangulation(base_data, ref_data1, ref_data2)
# st.write(matched_data)


















# from fuzzywuzzy import fuzz

# # Define a function to perform fuzzy matching
# def fuzzy_match(name, ref_data):
#     best_score = 0
#     best_match = None
    
#     # Iterate through each name in the reference dataset
#     for idx, row in ref_data.iterrows():
#         # Calculate similarity score between the name and each name in the reference dataset
#         score = fuzz.ratio(name, row['Name'])
        
#         # Update best match if current score is higher
#         if score > best_score:
#             best_score = score
#             best_match = row
            
#     return best_match

# # Iterate through each row in the base dataset
# for idx, row in base_data.iterrows():
#     # Perform fuzzy matching for name
#     matched_record = fuzzy_match(row['Name'], ref_data1)
    
#     # If a match is found, append matched attributes to the base dataset
#     if matched_record is not None:
#         base_data.at[idx, 'Matched_Name'] = matched_record['Name']
#         base_data.at[idx, 'Matched_Father_Name'] = matched_record['Father Name']
#         base_data.at[idx, 'Matched_Mother_Name'] = matched_record['Mother Name']
#         base_data.at[idx, 'Matched_Address'] = matched_record['Address']

# # Display the updated base dataset with matched attributes
# print(base_data)

# %%
base_data
# Out:
#           Name     Father Name      Mother Name      Address   Matched_Name  \
# 0     John Doe        John Sr.         Mary Doe  123 Main St        Jon Doe
# 1   Jane Smith   Michael Smith  Elizabeth Smith   456 Elm St      Jen Smith
# 2  Bob Johnson  Robert Johnson    Susan Johnson   789 Oak St  Bobby Johnson
# 3  Alice Brown   William Brown      Helen Brown  321 Pine St     Ally Brown
#
#   Matched_Father_Name Matched_Mother_Name Matched_Address
# 0            John Sr.            Mary Doe     123 Main St
# 1          Mike Smith           Liz Smith      456 Elm St
# 2         Rob Johnson         Sue Johnson      789 Oak St
# 3          Will Brown         Helen Brown     321 Pine St

# %% [markdown]
# ## Code to load all the csv files from the directory over here

# %%
import os
import pandas as pd

directory = '../data/Tables-SamagraMaster/'

csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

for file in csv_files:
    file_name = os.path.splitext(file)[0]
    globals()[file_name + '_df'] = pd.read_csv(os.path.join(directory, file))

# Example usage:
# Access DataFrame loaded from 'example.csv'
# print(example_df.head())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13716\3539013722.py:10: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[file_name + '_df'] = pd.read_csv(os.path.join(directory, file))

# %%
Relation_df
# Out:
#     ID    Relation_Name Relation_Name_Hi  Is_Male Relation_Name_abbr  \
# 0    1          Husband              पति      1.0            Husband
# 1    2             Wife         पत्‍नी        0.0               Wife
# 2    3              Son            पुत्र      1.0                Son
# 3    4         Daughter           पुत्री      0.0           Daughter
# 4    5          Brother              भाई      1.0            Brother
# 5    6           Sister              बहन      0.0             Sister
# 6    7           Mother             माता      0.0             Mother
# 7    8           Father             पिता      1.0             Father
# 8    9             Self            स्वयं      NaN               Self
# 9   10  Daughter in Law        पुत्र-वधू      0.0    Daughter in Law
# 10  11       Son in Law            दामाद      1.0         Son in Law
# 11  12         Grandson             पोता      1.0           Grandson
# 12  13    Granddaughter             पोती      0.0      Granddaughter
# ...

# %%
import pandas as pd
import os

directory = '../data/Tables-SamagraMaster/'

csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

dfs = []
for file in csv_files:
    file_name = os.path.splitext(file)[0]
    df = pd.read_csv(os.path.join(directory, file))
    dfs.append(df)

concatenated_df = pd.concat(dfs, ignore_index=True)

print(concatenated_df.head())
# Out:
#     ID Category_id  Caste_Code  \
# 0  186           3        92.0
# 1    1           3         1.0
# 2    2           3         2.0
# 3    3           3         3.0
# 4    4           3         4.0
#
#                                             OldCaste  \
# 0                                        Bahawalpuri
# 1  Ahir, Brajwasi, Gawli, Goli, Jadav (Yadav) Bar...
# 2                                      Asara, Asaada
# 3                                 Bairagi (Vaishnav)
# 4  Banjara,Banjari,Mathura, Nayak, Naykada, Dhuri...
#
#                                                Caste Category_Name  \
# 0                                        Bahawalpuri           NaN
# 1  Ahir, Brajwasi, Gawli, Goli, Jadav (Yadav) Bar...           NaN
# 2                                      Asara, Asaada           NaN
# 3                                 Bairagi (Vaishnav)           NaN
# 4  Banjara,Banjari,Mathura, Nayak, Naykada, Dhuri...           NaN
#
# ...
