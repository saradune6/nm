# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
import numpy as np
pd.set_option('display.float_format', '{:.6f}'.format)
pd.set_option('display.float_format', lambda x: "{:.6f}".format(x) if not pd.isna(x) else "NaN")

# %%
import os
import pandas as pd

directory = '../data/Tables-Sampledata/'

csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

for file in csv_files:
    file_name = os.path.splitext(file)[0]
    globals()[file_name + '_df'] = pd.read_csv(os.path.join(directory, file))

# %%
for file in csv_files:
    print(file)
# Out:
# AahaarAnudan.csv
# Ayusman.csv
# Cast.csv
# CMKIssan.csv
# Domicile.csv
# Family.csv
# Family_Member.csv
# Income.csv
# lby.csv
# Mptass.csv
# Pension.csv
# Sambal.csv
# SJED.csv
# StreenVendor.csv

# %%
AahaarAnudan_df.columns
# Out:
# Index(['ApplicationID', 'Beneficiary_Name', 'Father/HusbandName',
#        'DateOFBirth', 'District', 'Block', 'GP', 'Village', 'Cast', 'SubCaste',
#        'SamagraID', 'SamagraFamilyID', 'eEKYC_Status', 'Profile_Status',
#        'eKYC_Date', 'Project_status', 'DOB', 'Gender',
#        'RefKey_of_Beneficiaries', 'Aadhaar_Anudaan_Registration_Date',
#        'Insert_Date_Time', 'DePtID', 'SchemeID', 'Active', 'Remark'],
#       dtype='object')

# %%
Ayusman_df.columns
# Out:
# Index(['ahl_tin', 'ahl_hhid', 'name_ben', 'father_name_secc',
#        'mother_name_secc', 'dob_ben', 'gender_ben', 'district_code',
#        'village_code', 'ward_code', 'rural_urban', 'pmrssm_id', 'updateddate',
#        'matched_Samagra', 'DePtID', 'SchemeID'],
#       dtype='object')

# %%
Cast_df.columns
# Out:
# Index(['C_Id', 'Request_Id', 'Samagra_ID', 'Reg_No', 'Certificate_issue',
#        'Name_H', 'Name_E', 'FName_H', 'FName_E', 'MName_H', 'MName_E',
#        'Category_E', 'Category_H', 'Caste_Code_in_State_List', 'Caste_Name_H',
#        'Caste_Code_in_Centre_List', 'Caste_Name_E', 'Migration_Case',
#        'CertUrl', 'Insert_Date', 'Cancel_Flag', 'Request_Member_Id',
#        'Verify_By', 'District_Name_E', 'Identified', 'DePtID', 'SchemeID',
#        'ByAPI', 'name_match'],
#       dtype='object')

# %%
CMKIssan_df.columns
# Out:
# Index(['ApplicantName', 'SamagraId', 'RegNo', 'SchemName', 'SchemType',
#        'Amount', 'DateofBenefit'],
#       dtype='object')

# %%
Domicile_df.columns
# Out:
# Index(['D_Id', 'Request_Id', 'Samagra_ID', 'Certificate_No',
#        'Certificate_issue', 'Name', 'FName_H', 'District_Name_E',
#        'District_Name_H', 'CertUrl', 'Insert_Date', 'WName', 'Child_Name',
#        'Child_Age', 'Cancel_Flag', 'Request_Member_Id', 'Verify_By',
#        'Identified', 'DePtID', 'SchemeID'],
#       dtype='object')

# %%
Family_df.columns
# Out:
# Index(['id', 'district_id', 'Temporary_ID', 'village_ward_id',
#        'Gadna_Block_ID', 'Sub_GB_No', 'House_No', 'House_Sub_No',
#        'House_No_Section', 'House_Address', 'house_hold_number',
#        'npr_family_code', 'pin_code', 'member_count', 'head_family_member_id',
#        'category_id', 'Category_Code', 'st_ptg_id', 'is_sc_bb',
#        'is_sc_insanitory_works', 'is_vimukt', 'is_minority', 'religion_id',
#        'is_migrated', 'migration_reason_id', 'nominee_family_member_id',
#        'is_native_of_MP', 'year_since_mp_resident', 'is_BPL', 'BPL_Survey_No',
#        'BPL_Survey_Year', 'Toilet_Status', 'Is_Water_Available',
#        'House_Status', 'Property_tax_SNO', 'Water_tax_SNO', 'Nigam_License_No',
#        'Is_Tenant', 'is_locked', 'is_verified', 'is_deleted', 'insert_time',
#        'insert_by_user_id', 'import_phase', 'Varified_By', 'Varified_On',
#        'head_family_member_name', 'FPS_Id', 'is_move', 'is_updated',
# ...

# %%
Family_Member_df.columns
# Out:
# Index(['id', 'district_id', 'Temporary_ID', 'family_id', 'village_ward_id',
#        'Voter_List_Number', 'NPR_member_code', 'samagra_code', 'first_name',
#        'last_name', 'first_name_Hi', 'last_name_Hi', 'is_head', 'gender_id',
#        'dob', 'relation_id', 'marital_status_id', 'father_id', 'mother_id',
#        'spouse_id', 'father_name', 'mother_name', 'spouse_name',
#        'mobile_number', 'email_address', 'education_status_id',
#        'educational_institution_type_id', 'class_in_school', 'school_details',
#        'School_Type', 'DISE_Code', 'profession_id', 'is_disabled',
#        'annual_income', 'nirashrit_before_2007_nonBPL', 'Aadhaar_status_id',
#        'Aadhaar_Enrollment_No', 'is_updated', 'Verified_By', 'Verified_On',
#        'is_destitute', 'is_active', 'is_locked', 'is_Death', 'is_deleted',
#        'Approve_Status', 'Import_phase', 'insert_time', 'update_time',
#        'inserted_by_user_id', 'enc_aadhaar_id', 'Whats_Up_Mobile_No',
# ...

# %%
Income_df.columns
# Out:
# Index(['I_Id', 'Request_Id', 'Samagra_ID', 'Certificate_No',
#        'Certificate_issue', 'Name', 'FName_H', 'Address', 'Annual_Income',
#        'District_Name_E', 'District_Name_h', 'CertUrl', 'Insert_Date',
#        'Cancel_Flag', 'Request_Member_Id', 'Verify_By', 'Identified', 'DePtID',
#        'SchemeID'],
#       dtype='object')

# %%
lby_df.columns
# Out:
# Index(['BeneficiaryID', 'FamilySamagra_ID', 'Samagra_ID', 'Applicant_Name',
#        'DOB', 'Gender', 'Caste', 'HeadFamilyMemberName', 'RelationCode',
#        'MobileNo', 'Alternet_MobileNumber', 'WhatsUpMob', 'RefKey',
#        'Pension_Beneficiary', 'Pension_Type_Id', 'AadharAndBanklinking_Status',
#        'DBT_Status', 'DePtID', 'SchemeID', 'RegistrationDate', 'Rec_Status',
#        'Rec_Remark', 'Phase'],
#       dtype='object')

# %%
Mptass_df.columns
# Out:
# Index(['uid', 'DistrictCode', 'DistrictNameEnglish', 'BlockCode',
#        'BlockNameEnglish', 'adh_name', 'father_name', 'MPTAASProfileId ',
#        'samagraMemberID', 'samagraFamilyID', 'ProfileRegistrationDate',
#        'name_E', 'father_nameE', 'mother_nameE', 'cert_no', 'issuance_date',
#        'CasteEnglish', 'CasteHindi', 'AadhaarReference', 'AadhaarToken',
#        'Adhar matched Record', 'Name matched(100%) Record',
#        'Name matched_percentage', 'Identified', 'DePtID', 'SchemeID',
#        'insert_Date', 'Active'],
#       dtype='object')

# %%
Pension_df.columns
# Out:
# Index(['family_member_id', 'Pension_Type_id', 'pension_type', 'SchemeID',
#        'DePtID'],
#       dtype='object')

# %%
Sambal_df.columns
# Out:
# Index(['id', 'District_ID', 'VW_ID', 'Family_ID', 'first_name', 'last_name',
#        'Father_Name', 'Mobile_number', 'Gender_ID', 'Scheme_Id',
#        'Sub_Scheme_Id', 'SubSchemes', 'LB_ID', 'Family_Member_ID',
#        'ApplicationDate', 'Applicant_Name', 'Amount', 'Sanctioned_Date'],
#       dtype='object')

# %%
SJED_df.columns
# Out:
# Index(['District Name', 'LB Name', 'GP/Zone Name', ' Village/Ward Name',
#        'Beneficiary_SamagrID', 'Beneficiary_Name', 'DoB',
#        'Beneficiary_Mobile_Number', 'matched_Samagra', 'Scheme_Name', 'DePtID',
#        'SchemeID'],
#       dtype='object')

# %%
StreenVendor_df.columns
# Out:
# Index(['VendorProfileID', 'VendorType', 'VendorName', 'SamagraID',
#        'CertificateNo', 'CertificateDate', 'AadharRefrenceNo',
#        'RegistrationDate', 'ApproverName', 'Designation', 'Flag',
#        'matched_Dob', 'Adhar matched Record', 'Name matched(100%) Record',
#        'Name matched_percentage', 'Identified', 'DePtID', 'SchemeID'],
#       dtype='object')

# %%
Family_Member_df.head()
# Out:
#           id  district_id  Temporary_ID  family_id  village_ward_id  \
# 0  100686666            1        686666   30117241           107579
# 1  101094169            1       1094169   20257923           107874
# 2  101099177            1       1099177   20259742           107874
# 3  101100633            1       1100633   20259742           107874
# 4  101147505            1       1147505   28016000           114372
#
#   Voter_List_Number  NPR_member_code  samagra_code      first_name  \
# 0               NaN              NaN           NaN          Barsha
# 1               NaN              NaN           NaN  Deleted-Gurnam
# 2  MP/01/001/048766              NaN           NaN  Shambhoo Singh
# 3               NaN              NaN           NaN         SUGREEV
# 4               268              NaN           NaN          jamila
#
#        last_name first_name_Hi last_name_Hi  is_head  gender_id         dob  \
# ...

# %%
df1=pd.merge(Family_Member_df,Family_df,left_on="family_id",right_on="id",how="left")

# %%
df1.head(1)
# Out:
#         id_x  district_id_x  Temporary_ID_x  family_id  village_ward_id_x  \
# 0  100686666              1          686666   30117241             107579
#
#   Voter_List_Number  NPR_member_code  samagra_code first_name last_name  \
# 0               NaN              NaN           NaN     Barsha     Rajak
#
#   first_name_Hi last_name_Hi  is_head  gender_id         dob  relation_id  \
# 0         बर्शा          रजक        0          2  2001-01-01            4
#
#    marital_status_id  father_id  mother_id        spouse_id father_name  \
# 0                  2          0  141513241 141518229.000000         NaN
#
#     mother_name spouse_name  mobile_number  email_address  \
# 0  Geeta Dhobee      Ankesh            NaN            NaN
#
#    education_status_id  educational_institution_type_id  class_in_school  \
# 0             1.000000                         1.000000         5.000000
#
#    school_details  School_Type    DISE_Code  profession_id  is_disabled  \
# ...

# %%
# lby_df left

# %%
df2=pd.merge(df1,lby_df,left_on="family_id",right_on="FamilySamagra_ID",how="left")

# %%
df3=pd.merge(df2,AahaarAnudan_df,left_on="FamilySamagra_ID",right_on="SamagraFamilyID",how="left")

# %%
df4=pd.merge(df3,Ayusman_df,left_on="FamilySamagra_ID",right_on="ahl_hhid",how="left")

# %%
df5=pd.merge(df4,Mptass_df,left_on="FamilySamagra_ID",right_on="samagraFamilyID",how="left")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22512\1431028766.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'SchemeID_x', 'DePtID_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df5=pd.merge(df4,Mptass_df,left_on="FamilySamagra_ID",right_on="samagraFamilyID",how="left")

# %%
df5.head(1)
# Out:
#         id_x  district_id_x  Temporary_ID_x  family_id  village_ward_id_x  \
# 0  100686666              1          686666   30117241             107579
#
#   Voter_List_Number  NPR_member_code  samagra_code first_name last_name  \
# 0               NaN              NaN           NaN     Barsha     Rajak
#
#   first_name_Hi last_name_Hi  is_head  gender_id         dob  relation_id  \
# 0         बर्शा          रजक        0          2  2001-01-01            4
#
#    marital_status_id  father_id  mother_id        spouse_id father_name_x  \
# 0                  2          0  141513241 141518229.000000           NaN
#
#     mother_name spouse_name  mobile_number  email_address  \
# 0  Geeta Dhobee      Ankesh            NaN            NaN
#
#    education_status_id  educational_institution_type_id  class_in_school  \
# 0             1.000000                         1.000000         5.000000
#
#    school_details  School_Type    DISE_Code  profession_id  is_disabled  \
# ...

# %%
# StreenVendor_df left

# %%
df6=pd.merge(df5,StreenVendor_df,left_on="id_x",right_on="SamagraID",how="left")

# %%
df7=pd.merge(df6,CMKIssan_df,left_on="id_x",right_on="SamagraId",how="left")

# %%
df8=pd.merge(df7,Sambal_df,left_on="id_x",right_on="id",how="left")

# %%
df9=pd.merge(df8,Pension_df,left_on="id_x",right_on="family_member_id",how="left")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22512\2250784524.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'SchemeID_x', 'DePtID_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df9=pd.merge(df8,Pension_df,left_on="id_x",right_on="family_member_id",how="left")

# %%
df10=pd.merge(df9,SJED_df,left_on="id_x",right_on="Beneficiary_SamagrID",how="left")

# %%
df11=pd.merge(df10,Cast_df,left_on="id_x",right_on="Samagra_ID",how="left")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22512\4260683322.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'SchemeID_x', 'DePtID_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df11=pd.merge(df10,Cast_df,left_on="id_x",right_on="Samagra_ID",how="left")

# %%
df12=pd.merge(df11,Income_df,left_on="id_x",right_on="Samagra_ID",how="left")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22512\3394572881.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Identified_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df12=pd.merge(df11,Income_df,left_on="id_x",right_on="Samagra_ID",how="left")

# %%
df13=pd.merge(df12,Domicile_df,left_on="id_x",right_on="Samagra_ID",how="left")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22512\3811253457.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Samagra_ID_x', 'SchemeID_x', 'DePtID_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df13=pd.merge(df12,Domicile_df,left_on="id_x",right_on="Samagra_ID",how="left")

# %%
df13
# Out:
#            id_x  district_id_x  Temporary_ID_x  family_id  village_ward_id_x  \
# 0     100686666              1          686666   30117241             107579
# 1     101094169              1         1094169   20257923             107874
# 2     101099177              1         1099177   20259742             107874
# 3     101100633              1         1100633   20259742             107874
# 4     101147505              1         1147505   28016000             114372
# ...         ...            ...             ...        ...                ...
# 1040  101307024              1         1307024   20310063             114375
# 1041  101327902              1         1327902   20310649             107808
# 1042  101335871              1         1335871   20317161             114381
# 1043  101336298              1         1336298   20317161             114381
# 1044  101340212              1         1340212   20316508             107808
#
# ...

# %%
df13[df13['FullNameEn']=="Asha Jatav"]
# Out:
#           id_x  district_id_x  Temporary_ID_x  family_id  village_ward_id_x  \
# 102  101367971              1         1367971   20324210             114392
# 492  101706858              1         1706858   20408567             114375
# 691  101792362              1         1792362   20429479             114392
# 744  101850305              1         1850305   20443148             114392
#
#     Voter_List_Number  NPR_member_code  samagra_code first_name_x last_name_x  \
# 102               NaN              NaN           NaN         Asha       Jatav
# 492               NaN              NaN           NaN         Asha       Jatav
# 691               NaN              NaN           NaN         Asha       Jatav
# 744               NaN              NaN           NaN         Asha       Jatav
#
#     first_name_Hi last_name_Hi  is_head  gender_id         dob  relation_id  \
# 102           आशा         जाटव        0          2  1992-03-06            4
# ...

# %%
df13['FullNameEn'].value_counts()
# Out:
# Asha Jatav          4
# Badam Bai           3
# Pooran Jatav        3
# Sonu Batham         3
# Dinesh Jatav        2
#                    ..
# Laxmi Prajpati      1
# Reena Pirjapati     1
# Chhoti Prjapati     1
# Gobari Lal Jatav    1
# Preeti Regar        1
# Name: FullNameEn, Length: 999, dtype: int64

# %%
df13.duplicated().sum()
# Out:
# 6

# %%
# df13.to_csv("ReferenceData.csv",index=False)

# %%
df13
# Out:
#            id_x  district_id_x  Temporary_ID_x  family_id  village_ward_id_x  \
# 0     100686666              1          686666   30117241             107579
# 1     101094169              1         1094169   20257923             107874
# 2     101099177              1         1099177   20259742             107874
# 3     101100633              1         1100633   20259742             107874
# 4     101147505              1         1147505   28016000             114372
# ...         ...            ...             ...        ...                ...
# 1040  101307024              1         1307024   20310063             114375
# 1041  101327902              1         1327902   20310649             107808
# 1042  101335871              1         1335871   20317161             114381
# 1043  101336298              1         1336298   20317161             114381
# 1044  101340212              1         1340212   20316508             107808
#
# ...

# %%
df13.head(1)
# Out:
#         id_x  district_id_x  Temporary_ID_x  family_id  village_ward_id_x  \
# 0  100686666              1          686666   30117241             107579
#
#   Voter_List_Number  NPR_member_code  samagra_code first_name_x last_name_x  \
# 0               NaN              NaN           NaN       Barsha       Rajak
#
#   first_name_Hi last_name_Hi  is_head  gender_id         dob  relation_id  \
# 0         बर्शा          रजक        0          2  2001-01-01            4
#
#    marital_status_id  father_id  mother_id        spouse_id father_name_x  \
# 0                  2          0  141513241 141518229.000000           NaN
#
#     mother_name spouse_name  mobile_number  email_address  \
# 0  Geeta Dhobee      Ankesh            NaN            NaN
#
#    education_status_id  educational_institution_type_id  class_in_school  \
# 0             1.000000                         1.000000         5.000000
#
#    school_details  School_Type    DISE_Code  profession_id  is_disabled  \
# ...

# %% [markdown]
# ## Merging with the Master dataset over here

# %%
import os
import pandas as pd

directory = '../data/Tables-SamagraMaster/'

csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

for file in csv_files:
    file_name = os.path.splitext(file)[0]
    globals()[file_name + '_df'] = pd.read_csv(os.path.join(directory, file))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22512\471122471.py:10: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[file_name + '_df'] = pd.read_csv(os.path.join(directory, file))

# %%
Division_df.columns
# Out:
# Index(['id', 'state_id', 'division_code', 'division_name', 'division_name_hi'], dtype='object')

# %%
district_df.columns
# Out:
# Index(['ID', 'Division_ID', 'District_Name', 'District_NameH', 'IS_TRIBAL',
#        'DDO_Code', 'DDO_Code_SJ', 'LGD_Code', 'Census_Code',
#        'edistrict_state_code', 'edistrict_district_code'],
#       dtype='object')

# %%
LocalBody_df.columns
# Out:
# Index(['id', 'LB_Type', 'District_ID', 'LB_name_E', 'LB_name_H', 'Block_Id',
#        'DDO_Code', 'Is_Active', 'insert_date', 'Remarks', 'LSK_ID',
#        'Tehsil_Id', 'edistrict_tehsil_id_temp', 'Lgd_code', 'Trible'],
#       dtype='object')

# %%
GPZone_df.columns
# Out:
# Index(['id', 'LB_Id', 'Zone_Code', 'Zone_Name', 'Zone_Name_hi', 'Is_Zone',
#        'VidhanSabha_ID', 'Is_Active', 'insert_date', 'Remarks', 'lgd_code',
#        'inserted_on', 'update_date', 'Is_Tribal', 'GIS_lgd_code',
#        'Unnamed: 15'],
#       dtype='object')

# %%
VillageWard_df.columns
# Out:
# Index(['ID', 'gp_zone_id', 'Tehsil_Id', 'VW_Name_en', 'VW_Name_hi',
#        'Is_Village', 'Ward_Local_Known_Name', 'Ward_Local_Known_Name_Hi',
#        'Is_Active', 'Remarks', 'inserted_on', 'update_date', 'Correct_VW_ID',
#        'GIS_lgd_code', 'edistrict_Village_code', 'edistrict_Village_code_temp',
#        'Tehsil_Name', 'LLY_CensCD', 'LLY_vill_ward_Lgd_code',
#        'GIS_Tehsil_code', 'GIS_gp_zone_lgd_Code', 'VidhanSabha_Name',
#        'VidhanSabha_Code'],
#       dtype='object')

# %%
CastList_df.columns
# Out:
# Index(['ID', 'Category_id', 'Caste_Code', 'OldCaste', 'Caste'], dtype='object')

# %%
Category_df.columns
# Out:
# Index(['ID', 'Category_Name', 'Category_Name_Hi'], dtype='object')

# %%
gender_df.columns
# Out:
# Index(['id', 'Gender', 'Gender_Hi', 'Gender_S_Hi', 'Gender_abbr'], dtype='object')

# %%
Marital_df.columns
# Out:
# Index(['id', 'marital_status', 'marital_status_Hi'], dtype='object')

# %%
Relation_df.columns
# Out:
# Index(['ID', 'Relation_Name', 'Relation_Name_Hi', 'Is_Male',
#        'Relation_Name_abbr', 'Order_By', 'Is_For_UnMarried',
#        'Map_With_Relation_ID'],
#       dtype='object')

# %%
df13.head(1)
# Out:
#         id_x  district_id_x  Temporary_ID_x  family_id  village_ward_id_x  \
# 0  100686666              1          686666   30117241             107579
#
#   Voter_List_Number  NPR_member_code  samagra_code first_name_x last_name_x  \
# 0               NaN              NaN           NaN       Barsha       Rajak
#
#   first_name_Hi last_name_Hi  is_head  gender_id         dob  relation_id  \
# 0         बर्शा          रजक        0          2  2001-01-01            4
#
#    marital_status_id  father_id  mother_id        spouse_id father_name_x  \
# 0                  2          0  141513241 141518229.000000           NaN
#
#     mother_name spouse_name  mobile_number  email_address  \
# 0  Geeta Dhobee      Ankesh            NaN            NaN
#
#    education_status_id  educational_institution_type_id  class_in_school  \
# 0             1.000000                         1.000000         5.000000
#
#    school_details  School_Type    DISE_Code  profession_id  is_disabled  \
# ...

# %%
df13['id_x']

# %%
df14=pd.merge(df13,district_df,left_on="district_id_x",right_on="ID",how="left")

# %%
df14['Division_ID']

# %%
df15=pd.merge(df14,Division_df,left_on="Division_ID",right_on="id",how="left")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22512\328767392.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df15=pd.merge(df14,Division_df,left_on="Division_ID",right_on="id",how="left")

# %%
df16=pd.merge(df15,LocalBody_df,left_on="district_id_x",right_on="District_ID",how="left")

# %%
df16['']

# %%
df17=pd.merge(df16,GPZone_df,left_on="id",right_on="LB_Id",how="left")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22512\3814406647.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df17=pd.merge(df16,GPZone_df,left_on="id",right_on="LB_Id",how="left")

# %%
df17['village_ward_id_x']

# %%
df18=pd.merge(df17,VillageWard_df,left_on="village_ward_id_x",right_on="ID",how="left")

# %%
df18['category_id_x'].dtype
# Out:
# dtype('int64')

# %%
df18['category_id_x']=df18['category_id_x'].astype(str)

# %%
df18['category_id_x'].dtype
# Out:
# dtype('O')

# %%
df18.drop_duplicates(inplace=True)

# %%
df18.shape
# Out:
# (255638, 412)

# %%
df18.head(1)
# Out:
#         id_x  district_id_x  Temporary_ID_x  family_id  village_ward_id_x  \
# 0  100686666              1          686666   30117241             107579
#
#   Voter_List_Number  NPR_member_code  samagra_code first_name_x last_name_x  \
# 0               NaN              NaN           NaN       Barsha       Rajak
#
#   first_name_Hi last_name_Hi  is_head  gender_id         dob  relation_id  \
# 0         बर्शा          रजक        0          2  2001-01-01            4
#
#    marital_status_id  father_id  mother_id        spouse_id father_name_x  \
# 0                  2          0  141513241 141518229.000000           NaN
#
#     mother_name spouse_name  mobile_number  email_address  \
# 0  Geeta Dhobee      Ankesh            NaN            NaN
#
#    education_status_id  educational_institution_type_id  class_in_school  \
# 0             1.000000                         1.000000         5.000000
#
#    school_details  School_Type    DISE_Code  profession_id  is_disabled  \
# ...

# %%
df18['ID_x'].dtype
# Out:
# dtype('int64')

# %%
df18['ID_x']=df18['ID_x'].astype(str)

# %%
df19=pd.merge(df18,CastList_df,left_on="ID_x",right_on="ID",how="left")

# %%
df19['ID'].dtype
# Out:
# dtype('O')

# %%
Category_df['ID']=Category_df['ID'].astype(str)

# %%
df20=pd.merge(df19,Category_df,left_on="ID_x",right_on="ID",how="left")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22512\2522896366.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ID_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df20=pd.merge(df19,Category_df,left_on="ID_x",right_on="ID",how="left")

# %%
df20['gender_id']

# %%
df21=pd.merge(df20,gender_df,left_on="gender_id",right_on="id",how="left")

# %%
df21['marital_status_id']

# %%
df22=pd.merge(df21,Marital_df,left_on="marital_status_id",right_on="id",how="left")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22512\3416082589.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df22=pd.merge(df21,Marital_df,left_on="marital_status_id",right_on="id",how="left")

# %%
df22['relation_id']

# %%
df23=pd.merge(df22,Relation_df,left_on="relation_id",right_on="ID",how="left")

# %%
df23.tail()
# Out:
#              id_x  district_id_x  Temporary_ID_x  family_id  \
# 255633  101335871              1         1335871   20317161
# 255634  101335871              1         1335871   20317161
# 255635  101335871              1         1335871   20317161
# 255636  101335871              1         1335871   20317161
# 255637  101335871              1         1335871   20317161
#
#         village_ward_id_x Voter_List_Number  NPR_member_code  samagra_code  \
# 255633             114381               NaN              NaN           NaN
# 255634             114381               NaN              NaN           NaN
# 255635             114381               NaN              NaN           NaN
# 255636             114381               NaN              NaN           NaN
# 255637             114381               NaN              NaN           NaN
#
#        first_name_x last_name_x first_name_Hi last_name_Hi  is_head  \
# 255633       Preeti       Regar        प्रीति         रेगर        0
# ...

# %%
df23.shape
# Out:
# (255638, 436)

# %%
df23.drop_duplicates(inplace=True)

# %%
df23.shape
# Out:
# (255638, 436)

# %%
df23.to_csv("Entire-ReferenceData.csv",index=False)

# %%
# if the string are exactly same then consider them as matched
# if one of them is in upper or lower case elsewise same then also considered them as matched
# if two string are not matching due to spaces or hypens only then consider them as matched 
# else mismatched

# %%
## SOlving the Datetime task the ANKUSH over here

# %%
data=pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined
